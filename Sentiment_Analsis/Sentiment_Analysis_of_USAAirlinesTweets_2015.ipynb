# %% [markdown]
# # Name: Mohammed Ba Salem
# # ID: 1004681891
#
# ### Note: If you want to run it, please upload all necessary files excluding corpus. For writting the following code, I used Anaconda Jupyter Notebook 5.7.4 Python 3.X. I tried run it using IBM notebook, I faced issues with some plots. Thank you

# %% [markdown]
# # Assignment1: Sentiment Analysis
# The following code will compute the sentiment of text information for tweets posted in 2015 regarding US airlines. it will cover the below sections:
# 1. Data Clenaing
# 2. Exploratory Visualization Analysis
# 3. Model Preparation
# 4. Model Implementation
# 5. Results & Discussion

# %%
#!pip install nltk
#!pip install numpy
#!pip install pandas
#!pip install sklearn
# !pip install WordCloud
# Out:
# Requirement already satisfied: WordCloud in c:\users\mohammed\anaconda3\lib\site-packages (1.5.0)
# Requirement already satisfied: numpy>=1.6.1 in c:\users\mohammed\anaconda3\lib\site-packages (from WordCloud) (1.15.4)
# Requirement already satisfied: pillow in c:\users\mohammed\anaconda3\lib\site-packages (from WordCloud) (5.3.0)

# %%
#Importing necessary and used libraries along with machine learning modules
import pandas as pd
import numpy as np
import string 
import html
import re
import matplotlib.pyplot as plt 
import os
from nltk.tokenize import word_tokenize
import nltk
import seaborn as sns
from wordcloud import WordCloud

# sklearn libraries for model implementation
from sklearn.linear_model import LogisticRegression
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.feature_selection import SelectKBest, chi2
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report
from sklearn.naive_bayes import BernoulliNB
from sklearn.pipeline import Pipeline
# %matplotlib inline

# %% [markdown]
# # 1. Data Cleaning
# In this section a full integerated function named "parsed_data" was coded to do the following tasks:
# 1. Removing all html tags and attributes
# 2. Replacing all html character codes with an ASCII equivalent
# 3. Removing all urls
# 4. Removing extra white spaces
# 5. Removing punctuation marks and keeping only letters
# 6. Converting letters into lowercase
# 7. Removing Stop Words by using given list of stop words in assignment
# 8. Add @ to each text column as it will be used located airlinename
# 9. Tokenizing the tweet, and if an empty tweet after processing it will be preserved

# %%
# Definging a function to remove html tags
def remove_html_tags(text):
    clean = re.compile(r'/<[^>]+>/')
    return re.sub(clean, '',text)

hasht= set(string.punctuation)
# Defining a function to remove punctuation marks exclding '@'.  
def remove_punc(text):
    return "".join(list((map(lambda x:" " if x  in hasht else x, text ))))

# Defining a function to remove the stop words from tweets,all stop words were imported from given txt file of stop words. 
def remove_stopwords(twts):
    stop_words = open('stop_words.txt', 'r').read().split()      
    
    twts = twts.split()                     
    
    nonstop = " ".join(w for w in twts if not w in stop_words)     
    
    return nonstop

# %%
def parsed_data(text):
    
    # Removing URLs
    m = re.sub(r"http\S+", "", text)
    text = re.sub('((www\.[^\s]+)|(https?://[^\s]+))','', m)
    
    # Removing html tags
    text = remove_html_tags(text)
    
    # Replacing html character with an ASCII equivalent
    text = html.unescape(text)
    
    # Removing extra white spaces
    text = re.sub('[\s]+', " ", text)
    
    # Removing Punctuation marks
    text = remove_punc(text) 
    
    # Keep only letters
    text = re.sub("[^a-zA-Z]+", " ", text)
    # Converting to lowercase
    text = text.lower()

    
    # Removing stopwords
    text = remove_stopwords(text)
    #adding @ for purpose of locating airlines
    text = "@" + text 
    # Tokenize the tweet
    tokens = text.split()

    return (" ".join(tokens)).strip()

# %% [markdown]
# ## 1.1 Cleaning Generic Tweets
# 1. Generic tweet file will be imported and read file as data frame file by using pd library
# 2. To avoid complexity in removing noise and cleaning, some columns are not necessary here, so they will be dropped "ID, Query and User"
# 3. Replacing and Mapping "Class" column with "Sentiment" column that cotains values of 0 as negative and 4 as positive, however, we will conver them into 0 as negative and 1 as positive.
# 4. Converting the timestamp into Date for the purpose of visulizing the data later on
# 5. The data frame of generic tweets will be cleaned by using the funtion "parsed_data"

# %%
dtf=pd.read_csv('generic_tweets.txt')
dtf.head()
# Out:
#    class          id                          date     query             user  \
# 0      0  1467810369  Mon Apr 06 22:19:45 PDT 2009  NO_QUERY  _TheSpecialOne_
# 1      0  1467810672  Mon Apr 06 22:19:49 PDT 2009  NO_QUERY    scotthamilton
# 2      0  1467810917  Mon Apr 06 22:19:53 PDT 2009  NO_QUERY         mattycus
# 3      0  1467811184  Mon Apr 06 22:19:57 PDT 2009  NO_QUERY          ElleCTF
# 4      0  1467811193  Mon Apr 06 22:19:57 PDT 2009  NO_QUERY           Karoli
#
#                                                 text
# 0  @switchfoot http://twitpic.com/2y1zl - Awww, t...
# 1  is upset that he can't update his Facebook by ...
# 2  @Kenichan I dived many times for the ball. Man...
# 3    my whole body feels itchy and like its on fire
# 4  @nationwideclass no, it's not behaving at all....

# %%
# Dropping unnecessary columns from generic tweets data frame 
dtf= dtf.drop(['id','query','user'], axis=1)
#dtf

# Replacing and Mapping of Class column to sentiments column
dtf['sentiment'] = dtf['class'].apply(lambda x: 1 if x > 0 else 0)
dtf= dtf.drop(['class'], axis=1)
dtf['test']= 0

#Conversion of time to Date
dtf['date'] = pd.to_datetime(dtf['date'])
dtf['date'] =dtf['date'].apply(lambda x: x.date() )
dtf['date'] = dtf.date.sort_values()
dtf.head()
# Out:
# C:\Users\Mohammed\Anaconda3\lib\site-packages\dateutil\parser\_parser.py:1204: UnknownTimezoneWarning: tzname PDT identified but not understood.  Pass `tzinfos` argument in order to correctly return a timezone-aware datetime.  In a future version, this will raise an exception.
#   category=UnknownTimezoneWarning)
#          date                                               text  sentiment  \
# 0  2009-04-06  @switchfoot http://twitpic.com/2y1zl - Awww, t...          0
# 1  2009-04-06  is upset that he can't update his Facebook by ...          0
# 2  2009-04-06  @Kenichan I dived many times for the ball. Man...          0
# 3  2009-04-06    my whole body feels itchy and like its on fire           0
# 4  2009-04-06  @nationwideclass no, it's not behaving at all....          0
#
#    test
# 0     0
# 1     0
# 2     0
# 3     0
# 4     0

# %%
# Cleaning loop and store cleaned results in list clean_dtf
clean_dtf = dtf['text'].apply(lambda text:parsed_data(text))

# Converting clean list into data frame file and append all necessary files from uncleaned data frame
clean_dtf = pd.DataFrame(clean_dtf,columns = ['text'])
clean_dtf ['sentiment'] = dtf['sentiment']
clean_dtf ['date'] = dtf['date']
clean_dtf ['test'] = dtf['test']
clean_dtf.head()
# Out:
#                                                 text  sentiment        date  \
# 0  @switchfoot awww bummer shoulda david carr thi...          0  2009-04-06
# 1  @upset update facebook texting cry result scho...          0  2009-04-06
# 2  @kenichan dived times ball managed save rest b...          0  2009-04-06
# 3                             @body feels itchy fire          0  2009-04-06
# 4                      @nationwideclass behaving mad          0  2009-04-06
#
#    test
# 0     0
# 1     0
# 2     0
# 3     0
# 4     0

# %%
# Arrange columns for reading simplicity
clean_dtf=pd.DataFrame(clean_dtf,columns=['sentiment','date','test','text'])
clean_dtf.head()
# Out:
#    sentiment        date  test  \
# 0          0  2009-04-06     0
# 1          0  2009-04-06     0
# 2          0  2009-04-06     0
# 3          0  2009-04-06     0
# 4          0  2009-04-06     0
#
#                                                 text
# 0  @switchfoot awww bummer shoulda david carr thi...
# 1  @upset update facebook texting cry result scho...
# 2  @kenichan dived times ball managed save rest b...
# 3                             @body feels itchy fire
# 4                      @nationwideclass behaving mad

# %% [markdown]
# ## 1.2 Cleaning USA Airlines Data
# 1. US airlines file will be imported and read file as data frame file by using pd library
# 2. To avoid complexity in removing noise and cleaning, only the "ID" column will be dropped as it does not required for data analysis
# 3. Replacing "Sentiment" column of postive and negative into integers where 0 for "negative" and 1 for "positive"
# 4. As "negative_reason column contains NaN, we have to remove it and replace it with empty space (nonvalue).
# 5. The data frame of US airlines will be cleaned by using the funtion "parsed_data"

# %%
# Reading the US airlines file
USA_dtf=pd.read_csv('US_airline_tweets.csv')
USA_dtf.head()
# Out:
#              id sentiment negative_reason        user  retweet_count  \
# 0  5.703010e+17  positive             NaN    jnardino              0
# 1  5.703010e+17  negative      Bad Flight    jnardino              0
# 2  5.703010e+17  negative      Can't Tell    jnardino              0
# 3  5.703010e+17  negative      Can't Tell    jnardino              0
# 4  5.703010e+17  positive             NaN  cjmcginnis              0
#
#                                                 text
# 0  @VirginAmerica plus you've added commercials t...
# 1  @VirginAmerica it's really aggressive to blast...
# 2  @VirginAmerica and it's a really big bad thing...
# 3  @VirginAmerica seriously would pay $30 a fligh...
# 4  @VirginAmerica yes, nearly every time I fly VX...

# %%
# Dropping unnecessary columns from US airlines data frame 
USA_dtf= USA_dtf.drop(['id'], axis=1)

# Converting sentiments into integers of 0 and 1
USA_dtf['sentiment'] = USA_dtf['sentiment'].apply(lambda x: 1 if x =='positive' else 0)
USA_dtf['test']= 0

# Replacing  NaN values with ''
USA_dtf = USA_dtf.fillna('')
USA_dtf.head()
# Out:
#    sentiment negative_reason        user  retweet_count  \
# 0          1                    jnardino              0
# 1          0      Bad Flight    jnardino              0
# 2          0      Can't Tell    jnardino              0
# 3          0      Can't Tell    jnardino              0
# 4          1                  cjmcginnis              0
#
#                                                 text  test
# 0  @VirginAmerica plus you've added commercials t...     0
# 1  @VirginAmerica it's really aggressive to blast...     0
# 2  @VirginAmerica and it's a really big bad thing...     0
# 3  @VirginAmerica seriously would pay $30 a fligh...     0
# 4  @VirginAmerica yes, nearly every time I fly VX...     0

# %%
# Cleaning loop and store cleaned results in list clean_USA_dtf
USA_dtf1 = USA_dtf.text[:]
clean_USA_dtf =[]
for t in USA_dtf1:
    clean_USA_dtf.append(parsed_data(t))
clean_USA_dtf
# Out:
# ['@virginamerica ve commercials experience tacky',
#  '@virginamerica aggressive blast obnoxious entertainment guests faces recourse',
#  '@virginamerica big bad thing',
#  '@virginamerica seriously pay flight seats didn playing bad thing flying va',
#  '@virginamerica time fly vx ear worm won',
#  '@virginamerica well didn',
#  '@virginamerica amazing arrived hour early good',
#  '@virginamerica pretty graphics better minimal iconography',
#  '@virginamerica great deal thinking trip australia haven st trip',
#  '@virginamerica virginmedia flying fabulous seductive skies stress travel',
#  '@virginamerica',
#  '@virginamerica sfo pdx schedule mia',
#  '@virginamerica excited cross country flight lax mco ve heard great things virgin america daystogo',
#  '@virginamerica flew nyc sfo week couldn fully sit seat large gentleman side help',
#  '@flying virginamerica',
#  '@virginamerica amazingly awesome bos fll fly',
#  '@virginamerica fares three times carriers seats select',
#  '@virginamerica love graphic',
#  '@virginamerica love hipster innovation feel good brand',
#  '@virginamerica guys messed seating reserved seating friends guys seat free internet',
#  '@virginamerica status match program applied three weeks called emailed response',
#  '@virginamerica happened ur vegan food options ur site won eat hrs fail',
#  '@virginamerica amazing cold air vents vx noair worstflightever roasted sfotobos',
#  '@virginamerica bked cool birthday trip add elevate entered middle flight booking problems',
#  '@virginamerica help left expensive headphones flight iad lax today seat answering number lax',
#  '@virginamerica awaiting return phone call prefer online service option',
#  '@virginamerica great news america start flights hawaii year pacificbiznews',
#  '@virginamerica moodlighting fly best experience cool calming moodlitmonday',
#  '@virginamerica freddieawards best airline hands',
#  '@virginamerica chat support working site',
#  '@virginamerica view downtown los angeles hollywood sign rain mountains',
#  '@virginamerica hey time flyer week excited hard time flights elevate account help',
#  '@virginamerica elevategold good reason rock',
#  '@virginamerica wow blew mind',
#  '@virginamerica ladygaga carrieunderwood julie andrews ladygaga impressive carrieunderwood',
#  '@virginamerica excited lga dal deal ve book week loads thx',
#  '@virginamerica spotify stat guiltypleasures',
#  '@virginamerica ladygaga carrieunderwood lady gaga amazing',
#  '@virginamerica called weeks ago adding flights elevate haven help',
#  '@virginamerica ladygaga carrieunderwood love three beat classics',
#  '@virginamerica heyyyy guyyyys hour call',
#  '@virginamerica virgin hold minutes earlier flights la nyc tonight earlier pm',
#  '@virginamerica congrats winning travelzoo award best deals airline',
#  '@virginamerica fine lost bag',
#  '@virginamerica airline awesome lax loft step game dirty tables floors',
#  '@virginamerica worried great ride plane great crew airlines',
#  '@virginamerica awesome flew yall sat morning correct bill',
#  '@virginamerica going customer service speak human asap',
#  '@virginamerica supp biz traveler southwestair customer service jetblue neverflyvirginforbusiness',
#  '@virginamerica ve applied member inflight crew team interested flightattendant dreampath',
#  '@virginamerica best begrudgingly airline delayed late flight',
#  '@virginamerica interesting flying will cancelled flight flights planned neverflyvirginforbusiness',
#  '@virginamerica disappointing experience will shared business traveler meet neverflyvirgin',
#  '@virginamerica trouble adding flight wife booked elevate account help',
#  '@virginamerica site will',
#  '@virginamerica tv interesting video disappointed cancelled flightled flight flights jfk saturday',
#  '@virginamerica landed lax hour late flight bag check business travel friendly nomorevirgin',
#  '@virginamerica website btw website isn great user experience time redesign',
#  '@virginamerica check add bag website isn working ve desktop mobile',
#  '@virginamerica scanned passengers leave plane told remove bag st class bin uncomfortable',
#  '@virginamerica phone number find call flight reservation',
#  '@virginamerica today website useless answering phone',
#  '@virginamerica traveler flight late flight check bag missed morning appointments lost business sfo lax',
#  '@virginamerica direct flight fll sfo unexpected layover vegas fuel peeps bought vegas flight sneaky',
#  '@virginamerica late flight bag check lost business missed flight apt three people flight exp',
#  '@virginamerica amazing customer service raeann sf best customerservice virginamerica flying',
#  '@virginamerica called service hung awesome sarcasm',
#  '@virginamerica site tripping check plain text version reluctant enter card info',
#  '@virginamerica getaway deals lots cool cities cheapflights farecompare',
#  '@virginamerica getaway deals lots cool cities cheapflights farecompare',
#  '@virginamerica great week',
#  '@virginamerica phl horrible cold pleasecomeback',
#  '@virginamerica concerned fly plane delayed tech',
#  '@virginamerica best airline flown easy change reservation helpful representatives comfortable flying experience',
#  '@virginamerica rep kicked butt naelah represents team beautifully',
#  '@virginamerica beautiful front design cool book ticket secure',
#  '@virginamerica love team running gate las tonight waited delayed flight things entertaining',
#  '@virginamerica browser brand reputation built tech response doesn cross browser compatible website',
#  '@virginamerica flight flight booking problems site totally folks problem',
#  '@virginamerica customer service min delay connecting passengers long va',
#  '@virginamerica outstanding nyc jfk crew moved mountains san francisco tonight',
#  '@virginamerica absolute best team customer service time fly delighted',
#  '@virginamerica change flight scheduled hours min wait time phone calling intern help',
#  '@virginamerica completely awesome experience month bos las nonstop awesome flight depart time vabeatsjblue',
#  '@virginamerica failing customers check process link tsa pre check',
#  '@virginamerica fidifamilies terrible airline hotel hotline number',
#  '@virginamerica chrysichrysic assistance yesterday cancelled flightled flight hotel hotline shame',
#  '@virginamerica delayed flight likingyoulessandless',
#  '@virginamerica register service dog class ticket sfo dulles phone queue hour longer pls advise',
#  '@virginamerica rock making watch oscars flight redcarpet oscars oscars',
#  '@virginamerica xoxo',
#  '@virginamerica book seats flights buy check creates anxiety frustrated',
#  '@virginamerica paying extra bucks rt luggage afford hiring extra hand sfo lame',
#  '@virginamerica best customer service rep irmafromdallas takes cake',
#  '@virginamerica provide status flight cant imagine time web indicates dude weather dallas',
#  '@virginamerica amazing staff super helpful waltdisneyworld princesshalf spoiled comfort',
#  '@virginamerica paid premium fly country cancelled flight flight offer check fee upgrade love sad face',
#  '@virginamerica question book seat infant option seat',
#  '@rt virginamerica jessicajaymes',
#  '@virginamerica flight dc sunset globe backtowinter work refreshed',
#  '@virginamerica don understand dm answer damaged luggage policy',
#  '@virginamerica don policy destroyed luggage',
#  '@virginamerica checking tickets purchased customer happy',
#  '@virginamerica problems flight booking problems web site error contact phone phone minute wait',
#  '@virginamerica reschedule cancelled flightled flights online change button greyed',
#  '@virginamerica rang wait minutes book ticket vendor site',
#  '@virginamerica flight told today checked email tomorrow unacceptable',
#  '@virginamerica flight lga cancelled flighted stuck dallas called reschedule told flight today',
#  '@virginamerica don pairings include red wine white offered redwineisbetter',
#  '@virginamerica website',
#  '@virginamerica site wonked browsers css',
#  '@virginamerica disappointed agent designated silver status check dulles airport closed assist pasengers',
#  '@virginamerica normal receive reply central baggage baggageissues smh',
#  '@virginamerica logan airport waiting checkin flight checkin desk open',
#  '@virginamerica congrats business ewr sfo lax fuck united fl sfo ewr clincher',
#  '@virginamerica applied weeks ago haven heard flying week disappointed',
#  '@virginamerica follow',
#  '@virginamerica apologies worse airlines don respond cudtomers',
#  '@virginamerica shame va making people spend money stranded cities airlines landing jfk will reimburse',
#  '@virginamerica bad takes days confirmation email inquired weeks claim weeks',
#  '@virginamerica flight bos las tomorrow cancelled flightled notification wait times hour will rebook airline',
#  '@rt virginamerica ve met match status airline upgrade restr',
#  '@virginamerica fly elevate gold',
#  '@virginamerica lot apologies thrown customers sad worst airline',
#  '@virginamerica flight stuff wrong worst flight',
#  '@virginamerica will match americanairlines status cool',
#  '@virginamerica book flight guys website won lose business',
#  '@virginamerica suck',
#  '@virginamerica',
#  '@virginamerica dm issue persisting',
#  '@virginamerica rec cancelled flightlation notice left options fly ps driving la red eye mon kids',
#  '@virginamerica book flight site',
#  '@virginamerica flights flying boston tomorrow cancelled flightled flight didn',
#  '@virginamerica stink flight cancelled flighted psp jfk notification ability rebook disappointed expected better',
#  '@virginamerica love guy song dancing high school dance revue',
#  '@virginamerica website check',
#  '@virginamerica quick response faster sitting hold',
#  '@virginamerica cool picture virginamerica plane wing site',
#  '@virginamerica great work',
#  '@virginamerica goodness people love field amazing pressure texas beatstheothers crisis fly ny',
#  '@virginamerica great flight la boston pilots great job landing snow la seriously',
#  '@virginamerica awesome support guys rock',
#  '@virginamerica seats row don recline mention website soreback',
#  '@virginamerica flight delayed hours la mechanical problems handle pros tossed free drink',
#  '@virginamerica cancelled flight flights today precipitation scared',
#  '@virginamerica twitter team guys killed rescheduling asap',
#  '@virginamerica guys charged reschedule flight cancelled flighted refusing refund deal',
#  '@virginamerica access website safari iphone work mac ipad iphone add passbook',
#  '@virginamerica mobile site broken header elevateuser numofpointsavailable number points won checkin',
#  '@virginamerica forward flight will rescheduled diehardvirgin',
#  '@virginamerica cancelled flight flight vx delayed airport cancelled flightled gonna email call reschedule',
#  '@virginamerica problem link email check',
#  '@virginamerica change airline dc today united land dc cost ugh',
#  '@virginamerica forward flight today cancelled flightled subsequent',
#  '@virginamerica putting great deals pdx las las pdx love',
#  '@virginamerica afford fly friday going love airline',
#  '@virginamerica gonna deal dallas dc deal dc dallas sad',
#  '@virginamerica hold times call center bit',
#  '@virginamerica',
#  '@virginamerica site help',
#  '@virginamerica best flight attendant',
#  '@awesome rt virginamerica watch nominated films feet meetthefleet oscars',
#  '@virginamerica',
#  '@virginamerica reset password email arrives help',
#  '@virginamerica airline based silicon valley disruption fcmostinnovative incubator fastcompany',
#  '@virginamerica nicely',
#  '@virginamerica forward watching oscars flight tomorrow bubbly drink',
#  '@virginamerica reason delay departure vx jfk afternoon',
#  '@virginamerica todays flight palm springs jfk ny cancelled flightled',
#  '@virginamerica hahaha virginamerica guys amazing love guys',
#  '@virginamerica sounds fun',
#  '@virginamerica css site site unusable',
#  '@virginamerica flight vegas boston today checked online bag count didn register',
#  '@virginamerica classiq luv virgin america greetingz',
#  '@virginamerica check website working browsers problem continues',
#  '@virginamerica great customer service today helping travel sorted',
#  '@virginamerica guys sweet route rockies airplanemodewason',
#  '@virginamerica love music blasting gate boston waiting flight sanfrancisco iced coffee',
#  '@virginamerica passenger flt assaulted shouldn flown trust banned crew filed report faanews',
#  '@virginamerica current bug website select departure city selecting destination city',
#  '@virginamerica luggage severely dented missing wheel coming baggage claim san luggage agent miranda wasn help',
#  '@virginamerica easy itinerary shift impending weather quick painless free',
#  '@virginamerica good times vodkatonics entire flight sfo',
#  '@virginamerica great job adding luxuries aesthetics improve air travel experience',
#  '@virginamerica requested window seat confirmed window stuck middle seat good treat silver member',
#  '@virginamerica wtf paid direct flight purpose fuel exhausted frequent flier inconvenience',
#  '@virginamerica wrong website safari iphone',
#  '@virginamerica gate checking baggage full flight dfw lax early boarding sweet',
#  '@virginamerica checked expired',
#  '@virginamerica boo refunding seat upgrade fee buy place',
#  '@virginamerica',
#  '@virginamerica inflight team experience amazing',
#  '@virginamerica cutest salt pepper shaker guys better',
#  '@virginamerica moved seat notice better seat cabin select row selected disappointed',
#  '@virginamerica fav airline',
#  '@virginamerica hot female pilot sweet dca sfo',
#  '@virginamerica contacted central baggage dm renttherunway charging dress lost suitcase help',
#  '@virginamerica',
#  '@virginamerica going website ve lot errors minutes',
#  '@virginamerica virginatlantic checked flight sfo lax told atlantic flying club gold benefits',
#  '@virginamerica husband ordered three drinks screen awesome',
#  '@virginamerica soooo guys going leave seatbelt light flight barely call turbulence',
#  '@virginamerica funny story website broken missing javascript stylesheets checkin process dislike',
#  '@virginamerica love virgin gopro',
#  '@virginamerica check ct flight tmm desktop website working sort caching bug sos',
#  '@virginamerica guys check links emails broken',
#  '@virginamerica loved wait monday return flight watch inflight safety video sorrynotsorry',
#  '@virginamerica lost luggage days ago flight vx lax iad calling day response stuff',
#  '@virginamerica flight booking problems website broken chrome wanna',
#  '@virginamerica wanted routes planned year newark love flying guys hope',
#  '@virginamerica inappropriate board',
#  '@virginamerica happy spend day',
#  '@virginamerica understanding helped thx comps',
#  '@virginamerica absolutely will',
#  '@virginamerica broken link assets',
#  '@virginamerica manage itinerary website broken',
#  '@virginamerica check site time loads',
#  '@virginamerica carriers half price round trip fare stunned',
#  '@virginamerica wtf happening pdx late flight march sfo',
#  '@virginamerica free drinks flight free promo',
#  '@virginamerica ssal',
#  '@virginamerica luggage ve filed paperwork promised call email resolution response central luggage',
#  '@virginamerica',
#  '@virginamerica care suuperg flight rockstars travel',
#  '@virginamerica lovely soft views travel san sfo',
#  '@virginamerica requested mileage challenge status weeks ago online haven heard help',
#  '@virginamerica book tickets nyc facing super fun broken styling don worry ll',
#  '@virginamerica applied status match feb confirmation email day news guys dropped ball late flightly',
#  '@virginamerica adore forward flight austin weeks',
#  '@virginamerica glad mentioned virgin flight years transformative experience',
#  '@virginamerica check site',
#  '@virginamerica spending birthday night dal dca',
#  '@virginamerica couple messages email provided avail will year cheers',
#  '@virginamerica time flying virgin sanfrancisco smooth ride easily fav airline',
#  '@virginamerica seriously will direct flights sfo fll',
#  '@virginamerica fine purchase',
#  '@virginamerica experience hoping ws forced check small carry empty cabin space board',
#  '@virginamerica wjere luggage slow lax',
#  '@virginamerica spoke representative offered solution loyal customer flies virginatlantic well',
#  '@virginamerica deeply disappointed birthday promo applied trip booked mere days received email',
#  '@virginamerica happened direct flights sfo fll connecting help dontdothistome',
#  '@virginamerica promoting product problem southwest recommend noneother best',
#  '@virginamerica love guys pls direct routes las aus',
#  '@virginamerica course work virginatlantic obsessed entire virgin family',
#  '@virginamerica time flying tonight',
#  '@virginamerica embossed badges patches superior currently',
#  '@virginamerica vx jfk la dirty plane standards',
#  '@virginamerica flight vx headed la jfk dirtiest va plane sad great airline',
#  '@virginamerica squared picked tweeted tweeted sooner',
#  '@virginamerica avis rental continue button doesn work website book car times phone sucks',
#  '@virginamerica delayed',
#  '@virginamerica currently minute hold cust service add lap child reservation',
#  '@virginamerica karinslee course fun celebrating happy chinese year',
#  '@virginamerica flight booking problems second flight week sfo san chance gift promo code love guys',
#  '@virginamerica comenity bank joke change constant problems bank',
#  '@virginamerica grandma ella bday greeting flight crew stewardess eastern airlines',
#  '@virginamerica bought tix atx dallas route adding love yr airline yr website best transactional site',
#  '@virginamerica credit late flight flight yesterday great service wow moment unexpected gesture',
#  '@virginamerica submitted status match request haven heard flying monday accelerate',
#  '@virginamerica safety video loved cross country flight livewelltraveled sytycd',
#  '@virginamerica doesn fat yummy',
#  '@virginamerica omg omg nonstop dallas austin virgin',
#  '@virginamerica planes pretty thought',
#  '@virginamerica pulling hair book flight site doesn work iphone ipad don computer help',
#  '@virginamerica',
#  '@virginamerica help support ticket days incident',
#  '@virginamerica good texas moodlighting',
#  '@virginamerica open laptop seat paid premium',
#  '@virginamerica seat open laptop paid extra seat',
#  '@virginamerica needing austin trips dca ve',
#  '@virginamerica cool ur planes will',
#  '@virginamerica great well deserved',
#  '@virginamerica fyi info virginamerica email address contact password reset emails doesn exist emails bounce',
#  '@virginamerica status match weeks news flt week hope flt will count requirement cust svc help',
#  '@virginamerica website sucks donkey dicks thought best',
#  '@virginamerica crap channels pay watch uk tv',
#  '@virginamerica set',
#  '@virginamerica giants virgin america match heaven',
#  '@virginamerica goodness friday nwk sf boom',
#  '@virginamerica don iphone app making waste paper',
#  '@virginamerica seat entertainment system accept credit cards apostrophe surname apostrophefail',
#  '@virginamerica will vx lga slots today adding aus',
#  '@virginamerica luv ur people product thing charge herbal tea black tea caffeine drinker',
#  '@virginamerica excited expansion destinations spread wings',
#  '@virginamerica sad learn longer fly sfo phl hope returns',
#  '@virginamerica incredible customer service ve experienced refreshing',
#  '@virginamerica dreaming open route dallas austin houston',
#  '@virginamerica omg finally',
#  '@virginamerica kinda sucked earphone jack didn work flight future passengers',
#  '@virginamerica poor experience computer problem seat malfunction stuck missing meeting san diego',
#  '@virginamerica thankyou dal aus route day',
#  '@virginamerica awesome deals dal aus',
#  '@virginamerica love southwestair backyard consumers win biz competes',
#  '@virginamerica flying love austin excellent news',
#  '@virginamerica congrats vx route',
#  '@virginamerica offered charge additional ticket stranded thurs st time time',
#  '@virginamerica bad experience cake extortion carry items well',
#  '@virginamerica spend hours worrying items carryon broken stolen couldn carry plane lock bag',
#  '@virginamerica group told room bins plane room bags row',
#  '@virginamerica making flight lax jfk nightmare forcing check carry bag gate',
#  '@virginamerica lots flights book site working ve phone waiting minutes',
#  '@virginamerica flight artisanal cheese wine pairing',
#  '@virginamerica classy',
#  '@virginamerica lot jfk lhr flights lot faster mph strong tailwind',
#  '@virginamerica minus minutes elevate silver upgrade window opens freeneversucks',
#  '@virginamerica years fly dallas shit',
#  '@virginamerica jezziegoldz rough trip luckily virginamerica flight weather',
#  '@virginamerica perfect flight planes sun visors stay carriers raise',
#  '@nice rt virginamerica man steel faster wifi sciencebehindtheexperience',
#  '@virginamerica love dancing richard cool beans',
#  '@virginamerica don passbook love ll email future',
#  '@virginamerica free birthday points',
#  '@virginamerica man steel flies cities frequency',
#  '@virginamerica sharing site',
#  '@virginamerica dad segway best infographic',
#  '@virginamerica plans short haul airline europe defiantly fly guys',
#  '@virginamerica wifi better seating',
#  '@virginamerica started flight scolding overhead bin offered person seated',
#  '@virginamerica great return calls day couldn myvxexperience',
#  '@virginamerica airlines weren cancelled flighting flights bos helping customers virgin good luck',
#  '@virginamerica grouping virgin bos weather exposed actual cus serv model flight booking problems virgin',
#  '@virginamerica travelers boston storm shocked virgin complete apathy customers',
#  '@virginamerica umm reason contact contact definitive answer',
#  '@virginamerica change advance hours prior online earlier wanted change fees',
#  '@virginamerica loyal driving nyc pa fly virgin cut philly flights',
#  '@virginamerica guys perfect wervirgin',
#  '@virginamerica best customer service left industry',
#  '@virginamerica fly fargo fargoairport fares amazings',
#  '@virginamerica mood lighting point reclining seat kickin feet',
#  '@virginamerica flight scheduled pm departure time plane gate update long delay',
#  '@virginamerica group cancelled flightlation fees waived ticket booked reps help',
#  '@virginamerica pm newark la folks ewr incredible letsgohome',
#  '@virginamerica flying lax sfo awesome movie lineup long haul',
#  '@united',
#  '@united care happy customer',
#  '@united refund word dm resolve issue cancelled flightled flight useless assistant trip',
#  '@united delayed lack crew delayed long deicing improve service united',
#  '@united filled luck common',
#  '@united eri express connections hugely popular eri ewr hop',
#  '@united boarded flight au early',
#  '@united gate agent hooked alternate flights prevent constant issues rock',
#  '@united',
#  '@united ticket',
#  '@united worst nonrefundable class tickets select global fc system auto selects economy upgrade',
#  '@united cheertymedad buy tix days flight transfer tix flawed security logic flawed customer service',
#  '@united start claim weeks unrealistic supposed long car seat child ridiculous',
#  '@united follow airline beautifull',
#  '@united car seat lost united reimburse pair shoes necessity child',
#  '@united highbuddyyy totally sucks cousin worked phl united',
#  '@united wanted wonderful rosetta gate agent working flight dan ase wasappreciated',
#  '@united feb called united send voucher mail tiredofwaiting',
#  '@united internet great thing emailing executives company will respond timely manner',
#  '@united weak ya hey virginamerica',
#  '@united flew company united didnt earlier flight',
#  '@united book awards september flights aegeanairlines will award seats availab',
#  '@united drive total hours bag explain debacle talk',
#  '@united told repeatedly pilot late flight late flightr boarded defibrillator issue',
#  '@united preferred security tsa pre check didn pull silverairways partner flight platinum spoiled',
#  '@united newarkliberty airport indicate gate terminals flyingainteasy',
#  '@united newly married update preexisting international flight easy',
#  '@united united refuse reissue lost voucher plane didn mechanics badcustomerservice',
#  '@united instructed shattered computer',
#  '@united ve agents minutes agents rude thankfully ladan nice',
#  '@united iah charlotte baggage claim rep latrice customerservice existent ignored customer inappropriately touched customer',
#  '@united help issue austrian guess sit awhile longer',
#  '@united uctraveladvisor loved respond website long form business seats bad',
#  '@united refund flight vouchers flight airline expense today hour drive inconvenient',
#  '@united received call days infant car seat supposed child',
#  '@united well sitting ground time waiting gate tiredofthis',
#  '@united airport snow removal method good work folks cessna',
#  '@united guys book planes concern ll travel moving forward',
#  '@united measly certificate appreciate loyal customers wait hrs tarmac ua unacceptable',
#  '@united will email address username sign',
#  '@united claim interim expenses cost stuff',
#  '@united rude rude',
#  '@united boarding pass austrian airlines codeshare flight rebook incls hour layover stuck',
#  '@united received flights united breaks guitars unitedbreaksguitars wantmymoneyback',
#  '@united flew telaviv paid third suitcase didn plane impolite service',
#  '@united bag colo springs disabled search unfamiliar airport bag good outcome',
#  '@united shame flex tickets transfer rules calling neurosurgery icu isn',
#  '@united denver don handle baggage colo springs number call help',
#  '@united guys serious training customer service better options guys handle ur mistakes',
#  '@united problem avoided plague told find supervisor',
#  '@united zcc cancelled flight flight advance connect flight reschedule link isn helping help gf waited months',
#  '@united will flying',
#  '@united addition flight delayed hour arriving destination hrs late flight',
#  '@united flew united month experience awesome',
#  '@united travel booked united group dept okc ticket agent help connection lax',
#  '@united upset disability services told employees carrying medical equipment rude',
#  '@united thnx quick reply don assist intl grp will considerable inconvenience today',
#  '@united transfer flight ticket accompany yr active military mom emergency brain surgery wow',
#  '@united getmeontop weeks late flightr received miles mileageplus gift card starbucks card handed',
#  '@united hoping improvement',
#  '@united complained guy checked luggage throwing bags unfortunate coincidence hope',
#  '@united okc ticket agent roger mclarren sp helpful intl group travel problems find supervisor help',
#  '@united mobile apps construction ground os category expensive',
#  '@united fail united ticket agents okc helpful care problems american',
#  '@united working wc coach good thing bird landed ahead schedule wc stat',
#  '@united email customer care telling break sincerely hope help',
#  '@united silly flying delta today united club staff attendants surly unhelpful bothered pesky folk',
#  '@united phone number find call flight reservation',
#  '@united well missing buddies bday negligence attempt',
#  '@united will help customer service couldn number',
#  '@united helped baggage service desk bc tsa screening fll bags bag will ewr',
#  '@united mobile boarding pass disappeared phone standing board second time week hmm',
#  '@united record rozana newark lovely helpful choosekind',
#  '@united thx update',
#  '@united explain eager flight attendant vision ccicanine guide dog',
#  '@united point details servicedog book flight crew doesn read continued',
#  '@united bogota rude houston stuck hours guys',
#  '@united worst unitedflightsever ua las iad mechanical problems land delayed wtfodds',
#  '@united despite bag making newark good informative email tracking updates help',
#  '@united going ua outbound flight thurs delayed hrs long will delay worst unitedflightsever',
#  '@united worst unitedflightsever ua iad las mechanical problems switched aircraft delayed hours',
#  '@united crashed check',
#  '@united wow deal seats easy change customer happy',
#  '@united logan boarding gong lax carry enforcement bins full coats room bags better system',
#  '@united blackmailed paying extra return ticket nullified san francisco airport terrible service rep scam',
#  '@united disappointed didnt honor credit ur mistakes business',
#  '@united ua waiting supposed depart',
#  '@united credit trip mail',
#  '@united months waiting hear airline bit days requested terrible service',
#  '@united process waiting reply months pathetic customerservice',
#  '@united going website flight booking problems three tickets today ve booted system umpteen times',
#  '@united account number website email unavailable',
#  '@united received bag night missing',
#  '@united simonroesner ll upgrade seats economy sitting concrete bench',
#  '@united flight delayed pilots boarded sit scheduling',
#  '@united hard stay upset remorse',
#  '@united simple apology long hollow obvious don care well',
#  '@united isn time thing shocking pattern repeated neglect disrespect',
#  '@united fingers crossed intact disappointed experience enjoyed',
#  '@united incredibly easy stay comfort zone forced mine',
#  '@united july excuses system problems',
#  '@united sitting friends family members booked tickets october december bought',
#  '@united talking going nonstop flights sna sfo sfo ewr',
#  '@united will moving americanair united talk service',
#  '@united asked legitimate question systemwide localized problems unrelate flightd copy paste better',
#  '@united time call skis will airport faith united',
#  '@united guys amazing company continually mistakes fails held accountable error',
#  '@united yeah problem united international reputation problems',
#  '@united bbbne sd ks ia care hear listens issues caused',
#  '@united wonder sharing fb insta produce number characters limits story telling',
#  '@united telling number call left airport negligent pilot staff',
#  '@united email resent doesnt appear arrived',
#  '@united follow order dm',
#  '@united united coupon broken entertainment system hour flight seriously ridiculousness learncustomerservice',
#  '@united didn drop bag overnight leaving week supposed hold bag',
#  '@united dm details response book today',
#  '@united dm confirmation number',
#  '@united ve message twitter literate going stuck hrs',
#  '@united unhappy response complaint emailed feb awful customer service',
#  '@united private jet cool work ll',
#  '@united option united travelbank flight booking problems help recouping funds',
#  '@united common paper work ready don delay flights meetings choosechicago',
#  '@united yep correct email flight cancelled flightled doesn matter flight atl delayed thx',
#  '@united problem fll iah dm making connection',
#  '@united',
#  '@united grounded montreal ua missing connection ua st louis help private jet',
#  '@united frustrated nervous',
#  '@united difficult',
#  '@united child issue flying prepares ahead time reduce distress caused planes',
#  '@united cancelled flightled hours',
#  '@united guys traveling incredibly stressful uncomfortable good business',
#  '@united severe anxiety person help isn',
#  '@united seeking client cant refund filled form confident works indication',
#  '@united unrivalled access california flights uk airports nonstop connections year round',
#  '@united luckily flights time disappointed lack communication',
#  '@united checking flight atl cancelled flighted',
#  '@united service horrid wanted trip high note guess option',
#  '@united booked flight months ago requested seats fianc middle seats unacceptable',
#  '@united guys horrible',
#  '@united thnx info',
#  '@united pay wifi international business ticket pennypincher',
#  '@united top things ve lost luggage worse unitedairlines',
#  '@united kudos cancelled flightling flights dfw morning united panic',
#  '@united luggage broken youcouldntmakethis brokenwheel',
#  '@united day ll quoted',
#  '@united flight delayed remembered turn heat flight leaving seriously',
#  '@united awesome plane flight extremely nice captain steve connolly',
#  '@united speak real person resolved politely efficiently',
#  '@united hadn filed refund claim told charge dm disputed bank',
#  '@united bags flight iad second day clothes pretty inconvenient pretty curious unitedairlines',
#  '@united united flight saipan guam adventure capeair plane will operational',
#  '@united ve customer service phone number speak real person sorted',
#  '@united bags leave washington convenient left day ago unitedairlines lostluggage',
#  '@united dms owed refund provided contact number bank file claim',
#  '@united hours ago work bag hotel time will',
#  '@united pls properly train agents requested speak customer service transferred dead open hr',
#  '@united remembering load bag connecting flight wait forgot iceland fun clothes',
#  '@united cheese platter abundance entertainment options time flew',
#  '@united customer service atrocious disrupted travel plans lost luggage impossible talk human',
#  '@united terminal mia food open esp flights hours early recommended eat',
#  '@united ua flight currently stuck portland missed ride hour delay getmartyhome',
#  '@united responded requests contact numbers uk customer service number unitedairlines',
#  '@united bags lusaka',
#  '@united update suitcase online phone tracking told told yesterday',
#  '@united days set',
#  '@united thing guys shouldn charging drinks transatlantic flight',
#  '@united lhr arrival lounge fail waited mins shower left find hotel passengers carry planning',
#  '@united completed form doubt ua doesn care day vacation will ua won feel responsibility',
#  '@united definitely compliment thought bag lost airport happy customer',
#  '@united emailed ticket voucher unitedairlines care',
#  '@united will definitely trip remember ewr sti second season seat pays loyal',
#  '@united nope told time sleep airport assured room',
#  '@united expensive holiday worked year pay ruined compensation original case',
#  '@united united understand bag money',
#  '@united frankly worse customer service problems will happen deal defines company united',
#  '@united valid flight strange delay late flight inbound crew hours plane',
#  '@united lack help canned response desk',
#  '@united bad ua unforeseeable operational issue return flight',
#  '@united pay luggage delivered arrive wait additional days delivery',
#  '@united hotels people feel held hostage boarding passes leave fail',
#  '@united great airline',
#  '@united outbound bags lbs bags returning bag lbs logic writing machine human help required',
#  '@lindaswc united don hear poor experience share details customer care team',
#  '@united cancelled flightn left fend flt late flight runaround hrs employee blaming previous',
#  '@united ase find luggage',
#  '@united agent met gate issues delays ua online',
#  '@united lady phone tel aviv tel aviv united newark',
#  '@united melaniespring ll kn running plane running help',
#  '@united answers luggage days unacceptable',
#  '@united going',
#  '@united food taxis',
#  '@united offering rooms people fail',
#  '@united people pretty tired action solving problem missing day vacation skiing',
#  '@united bright side keeping promise hope good night',
#  '@united comment team working hard help solution hotel food fail',
#  '@united arriving hours late flight clt sitting tarmac move plane gate unhappy customer',
#  '@united airlines absolute worst idea neveragain unitedairlines',
#  '@united customer care team currently responding inquiries business days',
#  '@united flew united aus austin bergstrom cancun intl best flight big small',
#  '@united frustrating frequent flyer loyal continental upgrade equals paying times top purchase ticket',
#  '@united worse figure pack plane screws connectns claims hotl rooms san fran stranded pax',
#  '@united passengers hour delayed flight left hotel night hou airport wtf',
#  '@hey united flight iah pos leave late flight iah early pos earlier',
#  '@united lost bag process broken agent promised call hold bag waking delivery fail',
#  '@united people counter helpful flight austin sitting',
#  '@united darquenloveli regret hear assistance kn finally secure seat thx',
#  '@united good will open closed doors premier passengers safety briefings delayed flights annoyed',
#  '@united yea phoenix delays day people bullshit',
#  '@united consolation staff stellar hour delays encountered flights',
#  '@united flight ua gate ray flight iah didn wait',
#  '@united unfortunate tumitravel xmas gift razor ripped front pocket picture',
#  '@united',
#  '@united lost bags cancelled flightled flights delhi call centers poor united staff spread thin stressed',
#  '@united doesn mistake absurd doesn change fact inconveniently missing luggage tonight',
#  '@united constantly challenges upgrades charges order prevent dvt pay addtl',
#  '@united waited min crew members left gate items flight attendant sarcastically good luck walked',
#  '@united',
#  '@united favorite airline',
#  '@united seriously fail making strangers share room',
#  '@united needed asap will today flight',
#  '@united agent split reservation cancelled flight refund credit wks',
#  '@united share room',
#  '@united calling min phn wait options',
#  '@united guys flight bwi wait delayed flight san diego pretty',
#  '@united waiting find rep working hard upset wait tomorrow pm mammoth',
#  '@united early flt call appropriate reviewed nada avail day expect full refund',
#  '@united call fixed tweeting bs questions stall things worse phone number',
#  '@united yo yo yo stuck tarmac hours fly ohare going ride flypdx help helpimstuck united',
#  '@united highly unprofessional overbook flight seats feel rearrange schedule mismanagement',
#  '@united well considering agent claimed unable help waste time hear call corp',
#  '@united man wait book ticket jp life sabe',
#  '@united ice totally understand large number facing hours time overnight cancelled flightations',
#  '@united flt cancelled flightled email happened courtesy phn call book diff airline city',
#  '@united tag numbers find bags',
#  '@united better train support staff appropriate decorum consider revisiting terrible provide death certificate policy',
#  '@united well bar set low guys good apology game will change will guys learn',
#  '@united guys continue impress houston',
#  '@united making phones calls handle twitter email web',
#  '@united website deserves design html ftw',
#  '@united effing holidays missing full day skiing baggage team incompetence flyyow',
#  '@united agent helps person front finishes walks guy shocked',
#  '@united connection exact plane checked carry left chicago pretty ridiculous',
#  '@united encouraged ll cpap tonight',
#  '@united file claim carousel stopped bag email sched delivery',
#  '@united delay den cle manually enter baggage tags worst cust service day ker friendlyskies',
#  '@united flight delayed time min spare don delayed',
#  '@united lusaka zambia guess bags plane iad',
#  '@united late flight denver late flight newark disaster checking bags unacceptable',
#  '@united don ve flown problems worst airline period',
#  '@united filed claim hope receive luggage ridiculous purchase items sleep reimbursement',
#  '@united ua lhr bags loaded min late flight frigid air cabin plane feels falling apart upgrade long haul fleet',
#  '@united flight attendant served beverage tea checked ua notcool',
#  '@united load balancing system systemwide major impact united airlines flights cyberattack',
#  '@united unscheduled refueling missing connecting flights ward bed big pb sandwich',
#  '@united americanair spent hundreds rectify situation guys quiet',
#  '@united ua sitting ewr hour sked pilot computers clue will leave help',
#  '@united americanair ends traveled literally extra day half',
#  '@united upgrade list will fly st tomorrow min time statusmatchpaidoff',
#  '@united refunded vacation free room night making sleep dia',
#  '@united reminder fun ride',
#  '@united received luggage looked left snow arrived people refunded',
#  '@united updated aircraft wifi device entertainment outlets don charge devices',
#  '@united scan inside plane asked people plane going',
#  '@united gate changes delays crew thinks airline sucks',
#  '@united frustrated wasted days equipment failures',
#  '@united computers stopped updates flight info app ridiculous people updated',
#  '@united soooo days ve offered response assume poor treatment gate agents norm',
#  '@united terrific forward ua tomorrow great flight vancouver',
#  '@united calls hrs hold time day wait check suspect code share fare investigated time wasted',
#  '@united weeks cust care respond case requesting refund wi fi working update',
#  '@united appreciate efforts',
#  '@united correct ve spent hours book online receive error clicking final purchase button',
#  '@united today finest prevented gate agent advising passengers',
#  '@united real deal delay flight ua denver vegas',
#  '@united ua madrid arrived agent mass confusion fro ua employees maryjo rude unhelpful',
#  '@united system failure bad trend software projects flying airplane thing emergency takeoff',
#  '@united lots reports system failures delaying flights week currently sitting tarmac ogg hour',
#  '@united despite shaky connections ll tonight great job united touch',
#  '@united completely control price displayed',
#  '@united file claim clothing purchased',
#  '@united comically return flight ase united flights boarding adjacent gates clear plane board',
#  '@united grk file reference',
#  '@united contact discuss poor experiences customer service shot',
#  '@united ua pacific rim night cut constantly randomly spot repeatably',
#  '@united file report',
#  '@united send email bad experience send generic response reason ll fly',
#  '@united ticket refund unnecessary upgrade fee',
#  '@united horrible lost carseat expect loner carseat safety regulations illegal car seat',
#  '@united',
#  '@united don care thehipmunk link wrong price site site responsibility ensure correctness',
#  '@united telling ll night compensation',
#  '@united mllovelace baggage fee waived premier members jp point membership',
#  '@united wonderful bag claim people finally bag catch earlier flight original flight landed wastedtime',
#  '@united dmed',
#  '@united ll touch',
#  '@united karen salisbury iah amazing customer service daughter bag lost ua day',
#  '@united days late flightr bag left iad united helping tells story',
#  '@united left comment customer care contacting',
#  '@united lose gate checked bag den direct flight ugh',
#  '@united caught earlier flight gate checked bag ve lost hare original flight lands minutes frustrating',
#  '@united whitterbug spoke reservations team ve reinstated flight ey',
#  '@united captain behalf front office board heard laughed hard funnycaptain',
#  '@united follow dm missing bag',
#  '@united great fares',
#  '@united left item plane calling answering help',
#  '@united awesome ll book christmas vacatinn december ways devalue mileage',
#  '@united good number call speak people luggage saturday',
#  '@united secured room night thx helpful customer service rep dorns thanked goodenoughmother',
#  '@united damn bag',
#  '@united well employees denver baggage claim bag',
#  '@united diverted missed connecting flight told bag msy people cared',
#  '@united male agnt las threatens canadian cust cust takes pic gate agents help rebook friendlyskies',
#  '@united apollochplayers tonight cancelled flight leg reserv permission ph rps',
#  '@united stressed rude agents overwhelmed delyd flight las den yelling people pretty friendlyskies',
#  '@united landed boston night hours traveling rough tho',
#  '@united fail cancelled flightled flight frm gjt reserv iah sea reflight booking problems permission ph rps',
#  '@united fly list airlines wait connector late flight stuck iah',
#  '@united mere fact online issue statement vice calling talking directly good example',
#  '@united flew newark vail eagle',
#  '@united weekend dealing company',
#  '@united flight plane businesstravel goodenoughmother',
#  '@united proper response wait flight issue delta handle',
#  '@united customer service terrible stood inline hours flights hours late flightr bag disgutedindenver',
#  '@united inadequate accident',
#  '@united reebok rockinwellness denver international airport',
#  '@united responding helpful tool dustyob',
#  '@united boarding time min gate agent started check bag',
#  '@united agent las letting customers help rebook delayed flight den unfriendlyskies',
#  '@united empathizes disappointment stclass flight nonworking entertainmnt worth unfriendlyskies',
#  '@united doesn work',
#  '@united searched mileage tickets bom couldn find single saver awards play earn miles',
#  '@united flight arrives minutes early wait hour bags',
#  '@united issue fact called despite promises confirm bag location',
#  '@united waiting hear wallet stolen planes appreciate resolution',
#  '@united flysaa lost baggage heard things employees united flysaa',
#  '@united cs thinks miles repair damage will interesting travel united exp worst flight',
#  '@united signed notifications trip updated happened',
#  '@united care experience opened app find flight changed',
#  '@united responses waiting tomorrow morning flights overbooked',
#  '@united exact aircraft lax days ago fit problem agent today told nonsense policy change',
#  '@united helpful agents club helped baggage fees night life business silverairways',
#  '@united heard',
#  '@southwestair doesn charge ticket change fees incur mysterious costs incur united',
#  '@united exhausted frustrated link fb post abt travel issue',
#  '@united denied plane chance prove fits rookie read bio',
#  '@united exactly point fits premier access boarding group return ticket ve yrs',
#  '@united ve experienced worst customer service placing blame codeshare partners assuming responsibility unacceptable',
#  '@united currently board check terrible staff rude expensive luggage thrown',
#  '@united fucked voided ticket money apology will fly airline unitedairlines',
#  '@united worst customer svcs kevin rep call center investigated baggage lost help argument',
#  '@united sell tickets silverairways terrible service ua staff reach silver',
#  '@united demoted gold cuz hubby pqd tho enuf spent golds spousal discrimination angry',
#  '@united',
#  '@united favorite travel',
#  '@united lots terrible customer service newark despite raising complaint ignored tweet',
#  '@united lovely plane lga power outlets',
#  '@united tweet number won reveal address web',
#  '@united filed delayed bag report saturday flight cancelled flightled',
#  '@united lands ewr baggage claim file employee droppeditoffyet',
#  '@united rarely ceases amaze worse hope time fly',
#  '@united icloud help',
#  '@united response',
#  '@united atrocious customer service',
#  '@united albanyairport delayed departure check bags gate claiming space filled walk open spaces delay poorcustomerservice',
#  '@united cancelled flighted flights reason phone hour vacation',
#  '@united dfpietra response shaking head tsk better customer service apology',
#  '@united course bag frustrated',
#  '@united worst will avoid plague',
#  '@united worst airline',
#  '@united dm resolve correctly extremely disappointed service received terrible management',
#  '@united premier gold desk changes flight waives fees wrong flight jana acosta salt lake refuses service angry',
#  '@united will thing consistent consistent job well alwaysdelayedonunited',
#  '@united will angry',
#  '@united time flying united time terrible virginatlantic branson virginatlantic unitedairlines',
#  '@united committed continentalairlines flyer merger remember switched southwestair communicationfail',
#  '@united offer ticket coach cancelled flighting reservation glitch notfair',
#  '@united flight poor communication unaccounted lost time lots frustrated flyers standing',
#  '@united dm better',
#  '@united gate announcement states delay maintenance app late flight arriving aircraft truth unfriendly',
#  '@united easily worst company experienced lost personal possessions couldn care',
#  '@united app arriving aircraft early departing flight delayed late flight arriving aircraft unfriendly',
#  '@united airport hrs late flightr guys killing today stay positive',
#  '@united united service levels reaches etihad realistically lufthansa ill consider',
#  '@united called sick forgot call replacement hour late flight theworst',
#  '@united asked flight attendant typical compensation free tv unacceptable',
# ...
#  '@united heads didn check bags checked arrived claim people bags',
#  '@united drone united keambleam understand frustration bag team working hard bag',
#  '@united change hours seconds online thrilled loved agent',
#  '@united flight attendant doesn understand understanding english doesn deaf yelling english slowly',
#  '@united appropriate public dm united employee answer process hassle cancelled flighted',
#  '@united well big don terribly high expectations point',
#  '@united hate airline fee checked bag mentioned ticket rude agents',
#  '@united nice app delayed weather pilot waiting fuel ur control',
#  '@united robin ewr premiere desk helping earlier flight work huge',
#  '@united provide complimentary hotel accommodations ll stay overnight',
#  '@united originally share details link jimmy samartzis vice president customer experience expired',
#  '@united hr delay gate changes boarded boarded won change flight',
#  '@united help integrate app activate surf',
#  '@united ac minutes returning mojave desert pressurecooker heattrap',
#  '@united nope helped united badservice',
#  '@united airline missed connection steps remedy screw',
#  '@united didn help hours reply message middle night isn helpful',
#  '@united flight ua descending farce haven left ewr going worse',
#  '@united told ua flies direct dublin london complete shambles',
#  '@united min ewr baggage claim stillnobags ridiculous',
#  '@united standby denver delayed confirmed aspen flights cancelled flighted day confidence',
#  '@united plane delayed baggage loading issue',
#  '@united pt cancelled flight finally stndby pm flight day missedwork clientnothappy',
#  '@united kindness agents stranded family',
#  '@united don justifiable cost early flight seats airline charges conveniently passengers early',
#  '@united woke notification flight moved hrs early barely flight hrs layover sfo wanted hop earlier option',
#  '@united will delayed baggage claim land hopefully bag isn broken damaged lost will result complaints',
#  '@united send screen shot second call minutes',
#  '@united beauty dc united airlines',
#  '@united ll fill form land don duped hope will appreciate feedback will better',
#  '@united denver rebook weather issues better',
#  '@united suffer understand delays don understand speed process delays extent',
#  '@united cancelled flighted flights late flightr agent claimed flight cancelled flighted coworker flight delayed',
#  '@united urgency ridiculous ceo claims customer focused delays happen planes sit customers',
#  '@united wasn full refund delaying hours reason partial credit',
#  '@united flight scheduled haven moved flight moved sense',
#  '@united thx',
#  '@united hell',
#  '@united bulkhead seats bags floor don reserve head space seats ua impressed',
#  '@united helpful refresh boarding time info boarding passes delayed flights',
#  '@united flights year delays including cancelled flightations late flightst reason crew needed mandatory sleep mexico',
#  '@united great hear thankyou greatly appreciate replies feel settled',
#  '@united counter agents rdu deserve medal thankyou',
#  '@saga melissaafrancis bag delay united will reunion will forced shopping stay tuned',
#  '@united flight gate agent prevent onboard bag ve years flight crew reasonable',
#  '@united literally called preboarding',
#  '@united guys split charges credit cards making unnecessarily expensive people fly guys pts',
#  '@united ua feb point overselling flights bad making people wait hr kick boarding worse',
#  '@united brilliant thankyou classed carryon',
#  '@united listening compliant thing appreciate working',
#  '@united ve ve cancelled flightled flight',
#  '@united chance wait afternoon flight screwed hold',
#  '@united ua wait ground gate moved crap',
#  '@united mex nrt dates tbd usd difference quotations september compared mex bkk',
#  '@united better connection fwa boards ten minutes open plane landed hour late flight',
#  '@united united gold number ve hold minutes lost nowhereland gold reservation help',
#  '@united great ready',
#  '@united wow answered awesome americanair usairways customer service usairwaysfail',
#  '@united noooooooooooooooooooooope',
#  '@united planned occurs absolutely consistently yyj flight cancelled flightled daily',
#  '@united jms outsource united airlines customers loving outsource outsource outsource',
#  '@united follow tho dm',
#  '@united better senior manager gate retrain gate people',
#  '@united jms supporting mechanics maintenance workers united puts video timco wifi',
#  '@united',
#  '@united missed connection ugh',
#  '@united jms video outsourced favorite timco knack substandard maintenance work aircraft',
#  '@united formally complain customer service handler misconnected denied boarding lost bag help',
#  '@united lot unhappy cold people bridge freezing temps hour info',
#  '@united flight iad sat outdoor track hour',
#  '@united seriously wifi hr flight cle sfo airline wifi pls unwind bs',
#  '@united rebook sooner hr delayed flight linesforever customerservice fail',
#  '@united reason travel experience nightmare',
#  '@united pointless tweet americanair asked follow resolve',
#  '@united apology',
#  '@united cool',
#  '@united seriously wifi hr flight cle sfo airline wifi',
#  '@united boarding attendant shoe sock desk agents foot gross',
#  '@united unitedairlines pm abq walk missing change',
#  '@united hopefully baggage fees will waived tomorrow flight well compensation hotel room',
#  '@united fine plundering hard earned dollars fine',
#  '@united sfo yyj fight cancelled flightled times week bother',
#  '@united waiting pilot door plane broke global services status airline unsafe stunning',
#  '@united reimbursed hotel taxis cancelled flightation',
#  '@united awesome flight crew ua plane jurassic period called dinosaur plane',
#  '@united united unable flight reservation passenger yyz check counter wow smh customerservice',
#  '@united ticket refund request case',
#  '@united phone hour customer service figure awesome service',
#  '@united piss people farelock option fake',
#  '@united week shanghai sfo delay hrs bc engine today sfo sea delay sick pilot compensation care',
#  '@united thing confusing lost priority boarding mileage card member',
#  '@united hoping hear',
#  '@united rescheduled today frigid cold reason maintenance issue day',
#  '@united fact international bag sense going maintenance',
#  '@united contacted directly phone service laissez faire best problem isn cancelled flightled flight',
#  '@united international phone fritz chicago hrs figure',
#  '@united delayed response ua chicago san fran held hour tarmac lost bags',
#  '@united update told airport call today haven',
#  '@united help pick bags aspen airport coming today flight',
#  '@united gate iad released passengers board deplaning peopleon bridge flight board',
#  '@united public extend vacation week point advertise multiple flights honor',
#  '@united cancelled flights flt ewr crew tells wife yr ny catch aircanada yyz good customerservice dead',
#  '@united arriving day half late flightr supposed lesson day don verbal written confirmations united',
#  '@united arriving airport hours departure time missing flight bc don electronic ticket',
#  '@united hour delay voucher missing time family family precioustime',
#  '@united people schedule flight worth missed connections shameful',
#  '@united unfriendly screw family hates kids moms waiting ua pray better fyvrfn agent error tickt',
#  '@united gate agent ewr disabled wheel chair time board step step lol',
#  '@united won help',
#  '@united forces check baby bag overbooked flight complains wife baby united baby meals',
#  '@united love help today ewr will airline connections thx',
#  '@united today flight san francisco refuse board baby early time board baby carryon bag',
#  '@united scheduled flights reservation literally unreal',
#  '@united hotel issued yr tickets needed fixing hour agents nightmare',
#  '@united hours rebook hours problem arrive gate stopped infant sitting yr lap',
#  '@united arrived yyz flight taiwan reservation missing ticket numbers slow agent sukhdeep caused flt',
#  '@united',
#  '@united update',
#  '@united three people awesome working long hours easy twitter help ppl ewr',
#  '@united guess excuse understaffed costumer services people deal lots angry passengers weather',
#  '@united cancelled flightled wife daughter flt going follow dm details',
#  '@united departed awaiting inbound plane yesterday three hours arrived stay overnight',
#  '@united confirmed seat crisis averted beers won missed',
#  '@united english ll dm don ll plane appear',
#  '@united today will consecutive delayed flight win prize southwest air don fly sba',
#  '@united sitting plane pilot waitingonapilot denver siouxfalls whyairtravelsucks',
#  '@united understood reaching sooner',
#  '@united answer oops miles pays discomfort',
#  '@united received hotel food email miles trip hr delay miles cancelled flightlation',
#  '@united ua delayed crazy ve overnight delays unitedairlines',
#  '@united frustratingly delay happened gate onboard aircraft heads advance',
#  '@united den agent amazing mpagent check sucks seanmfmadden peterstraubmma jmercadomma tonysimsmma',
#  '@united ua delayed hours stretching trip midnight extremely exhausting',
#  '@united ha rebooked hr layover robbing night family late flight fly time',
#  '@united switched fly united delta trips disappointed ua delayed hours',
#  '@united traveling megzezzo injured gate agent chicago awesome helping ty roadwarrior',
#  '@united unitedairlines long will delayed',
#  '@united isn flight status updated delayed ua board',
#  '@united paid economy boarding group gate check bags virginamerica better',
#  '@united travelled scl iha feb ac sit night complaint fa real answer help',
#  '@united suck hour delay',
#  '@united worst airline crap website worthless app late flight flight suck shut',
#  '@united jh reaching assistance waiting minutes',
#  '@united stand pilot paperwork mins problem fixed mins ago flight delayed',
#  '@united reasonable wait mins bag check flight staff couldn police overhead bins',
#  '@united msg customer service will invoice dry cleaning won wet clothes airport',
#  '@united hour delay print piece paper',
#  '@united response',
#  '@united seat assign paying cust',
#  '@united reference number agent told drive airport reach deliver',
#  '@united better crew spent long time searching better altitude helped pax sharp drops',
#  '@united credit card charged transaction told charge will contacting',
#  '@united pqms pqds longer showing correctly mileageplus acct fixed',
#  '@united',
#  '@united sfo bos internet',
#  '@united worst worst reservation policies worst costumer service worst worst worst congrats delta bad',
#  '@united change reservations extremely frustrated airline',
#  '@united email update eta communication details apology info compensation rights long',
#  '@united late flight crew btv nite delayed todays flt will connection cun play hotel tonight ewr',
#  '@united called check worstcustomerservice',
#  '@united passengers rerouted match intended arrival time incur cost airlines',
#  '@united solved finally picked second time called response jh dulles works',
#  '@united work united flierfriendly program clue flight attendants',
#  '@united space doctors notes trip lost suitcase issues pleased united',
#  '@united flierfriendly garbage cry attendant find place medical supplies limited overhead',
#  '@united epic fail reagan jetway mins tarmac',
#  '@united link finally arrived brussels schedule',
#  '@united flight weeks lost bag status americanair neveragain worstcustomerservice',
#  '@united ua flight nightmare poor customer service confirmed seat issues',
#  '@united best customer experience twitter huge fan',
#  '@united flight night bad business will long time recommend united',
#  '@united frustrated sked change seats earlier departure double layover course seats cust svc help',
#  '@united working lisa working hard disappointing ewr',
#  '@united love st class breakfast',
#  '@united emailed customer care website form long wait rachelle resolved issue irritated united',
#  '@united flight cancelled flightled updated bwi late flight fine dca iad arriving earlier help',
#  '@united jj standing joking finding humor',
#  '@united point',
#  '@united dm glad hear bag finally delivered',
#  '@united talk customer service agent service service received flight week',
#  '@united cancelled flight flight wait rebooked front gate lose place',
#  '@united wasn comment question copy paste response',
#  '@united failed week iah intl trip delta small ual flight lax booked',
#  '@united supposed board brought plane hanger wtf flight lax ewr',
#  '@united flew sdf atl tampa delta left early arrived early crew helpful wifi worked',
#  '@united starting robotic response',
#  '@united control turbulence control customer experience lot scared people',
#  '@united currently ua minutes worst turbulence ve experienced communication flight deck',
#  '@united ticket agent terminal dismissed missed chance miami flight dr',
#  '@united told issue resolved write email bounces worstservice',
#  '@united flight clowns st class',
#  '@united hold time waiting resolve issue flight year son terribleservice noservice',
#  '@united cool',
#  '@united recognize terri dulles going raleigh flight',
#  '@united freq flyer sad cust needing assistance treated servicefail',
#  '@united day saga ll finally intentional gonna vacation days badservice',
#  '@united sick company lousy excuse customer service flying united',
#  '@united current hold time speaking rep tix reissued mins long option online',
#  '@united understand ppl mistakes don code reimbursed fault blatant lie',
#  '@united forgot add bag going sit jersey missed connection',
#  '@united jx today great honeymoon delay damper iy',
#  '@united shared pilot passengers',
#  '@united receipt upgraded return leg months late flightr receipt',
#  '@united book flight reserved seat check find seat wtf',
#  '@united gate agent rude standing waiting reflight booking problems missed flight sti awful',
#  '@united building time promises ceo service worse',
#  '@united wi fi aircraft didn work entire dca flight morning',
#  '@united cancelled flightled direct flight newark brussels night hours schedule eu compensation',
#  '@united dislike delays paid agreement paid destination time',
#  '@united epicfail cx flight frankfurt san francisco going chicago flight crew hours de icing delay',
#  '@united aware flight details three hours late flight crew shit',
#  '@united making flights delayed poor maintenance start',
#  '@united hilarious',
#  '@united hahahahaha ya',
#  '@united bag airport airport picking phone responding messages',
#  '@united funny paid check bag flight begging folks check bags free hour flight notcool',
#  '@united nope red stamp counter check wreck son',
#  '@united wasn cancelled flight change award ticket place sending link fee',
#  '@united unhappy mileage rules main reason flying united will business',
#  '@united assistance incompetence reschedule connection will fly united',
#  '@united ve officially displaced deltaassist better flight experience pleasant cabin crew timeliness ua switching',
#  '@united bag bouncer',
#  '@united showexpert going united mileage program pay ticket fraction pqd credit',
#  '@united retrain flight attendants room carry ons cool',
#  '@ua united cancelled flightled delayed flight booking problems miles acknowledge cancelled flightlation',
#  '@united will flight booking problems flight united affiliate chance united flight',
#  '@united send dm good',
#  '@united three delayed flights missed connections class flights compensation losing seats',
#  '@united hold hour day sort told fine fine arrive fly',
#  '@united weeks word dot update london fare cities updates',
#  '@united well start nice ticket system change flight',
#  '@united awful experience victoria check desk stl rude condescending',
#  '@united deliver house sombrons house',
#  '@united michelle train staff treat customers refreshing pleasure deal',
#  '@united guess follow order send dm won send',
#  '@united stopped flying united yr ago bc aggressive policy carryon bdl listening pssngrs forced chk preboard notcomingback',
#  '@united message bag tag looked',
#  ...]

# %%
# Converting clean list into data frame file and append all necessary files from uncleaned data frame
clean_USA_dtf = pd.DataFrame(clean_USA_dtf,columns = ['text'])
clean_USA_dtf ['sentiment'] = USA_dtf['sentiment']
clean_USA_dtf ['negative_reason'] = USA_dtf['negative_reason']
clean_USA_dtf ['test'] = USA_dtf['test']
clean_USA_dtf ['user'] = USA_dtf['user']
clean_USA_dtf ['retweet_count'] = USA_dtf['retweet_count']
clean_USA_dtf.head()
# Out:
#                                                 text  sentiment  \
# 0     @virginamerica ve commercials experience tacky          1
# 1  @virginamerica aggressive blast obnoxious ente...          0
# 2                       @virginamerica big bad thing          0
# 3  @virginamerica seriously pay flight seats didn...          0
# 4            @virginamerica time fly vx ear worm won          1
#
#   negative_reason  test        user  retweet_count
# 0                     0    jnardino              0
# 1      Bad Flight     0    jnardino              0
# 2      Can't Tell     0    jnardino              0
# 3      Can't Tell     0    jnardino              0
# 4                     0  cjmcginnis              0

# %%
# Arrange Columns for reading simplicity
clean_USA_dtf=pd.DataFrame(clean_USA_dtf,columns=['user','sentiment','test','retweet_count','negative_reason','text'])
clean_USA_dtf.head()
# Out:
#          user  sentiment  test  retweet_count negative_reason  \
# 0    jnardino          1     0              0
# 1    jnardino          0     0              0      Bad Flight
# 2    jnardino          0     0              0      Can't Tell
# 3    jnardino          0     0              0      Can't Tell
# 4  cjmcginnis          1     0              0
#
#                                                 text
# 0     @virginamerica ve commercials experience tacky
# 1  @virginamerica aggressive blast obnoxious ente...
# 2                       @virginamerica big bad thing
# 3  @virginamerica seriously pay flight seats didn...
# 4            @virginamerica time fly vx ear worm won

# %% [markdown]
# # 2. Exploratory Visualization Analysis
# It is always good practice to visualize your data as it can give you some guidlines about your dependant and independant parameters and how they are distribuated. Therefore, we can have a clear image on how to carry on the next step whcih is building machine learning alogarithm. And again visulaization analysis will be splitted into two parts:
# 1. Visualization of generic tweets.
# 2. visualization of US airlines tweets.

# %% [markdown]
# ## 2.1 Visualization of Generic Tweets
# As we examined the generic tweets in cleaning part, we realized that this data can be visualized based on the following appoach:
# 1. Total number of positive and negatives tweets. This visualization will give a clear picture probability distibuation in this data.
# 2. It will be visualized based on dates such that dates can be an indicator for high peak period for traveling or any customer operational expenses.

# %% [markdown]
# ### 2.1.1 Visualization of Total Positive & Negative Tweets
# From below plot and results, we can see that we have equal number of positive and negative tweets that is equal probability of 50% each.

# %%
# From microsoft excel pivot concept, I figure it out that it will be easier to develop a pivot table for specificed data to plot, such that old files are not mixed with new ones
piv_tab1 = pd.pivot_table(clean_dtf,values='test' , index=['date', 'sentiment'],aggfunc="count")
piv_tab2 = pd.pivot_table(clean_dtf,values='test' , index=['sentiment'],aggfunc="count")

dtf1 = pd.DataFrame(piv_tab1.to_records())
print(dtf1)

dtf2 = pd.DataFrame(piv_tab2.to_records())
print(dtf2)
# Out:
#           date  sentiment   test
# 0   2009-04-06          0   1426
# 1   2009-04-06          1   1934
# 2   2009-04-07          0   7149
# 3   2009-04-07          1  10162
# 4   2009-04-17          0   1244
# 5   2009-04-17          1   1840
# 6   2009-04-18          0   9040
# 7   2009-04-18          1  12714
# 8   2009-04-19          0  11427
# 9   2009-04-19          1  16042
# 10  2009-04-20          0   7817
# 11  2009-04-20          1  10643
# 12  2009-04-21          0   3504
# 13  2009-04-21          1   5083
# 14  2009-05-01          0   3254
# 15  2009-05-01          1   4462
# 16  2009-05-02          0  11398
# 17  2009-05-02          1  16036
# 18  2009-05-03          0  14779
# 19  2009-05-03          1  20554
# 20  2009-05-04          0   6438
# 21  2009-05-04          1    530
# 22  2009-05-09          0   4997
# 23  2009-05-10          0  10702
# 24  2009-05-11          0   1765
# 25  2009-05-13          0   1776
# 26  2009-05-14          0   3284
#    sentiment    test
# 0          0  100000
# 1          1  100000

# %%
# To depict the destribuation of probaility, a bar plot was used
my_bag=['Negative', 'Positive']
plt.bar(dtf2.sentiment, dtf2.test)
plt.xticks(dtf2.sentiment, my_bag)
plt.xlabel('Sentiment')
plt.ylabel('Number of Recorded Tweets')
plt.title('Distribution of Positive and Negative')
plt.show()
clean_dtf.sentiment.value_counts()
# Out:
# 1    100000
# 0    100000
# Name: sentiment, dtype: int64

# %% [markdown]
# ### 2.1.2 Visualization of Positive & Negative Tweets Based on Date
# The below plot demonstrate the how sentiments varied based on the date, as it can be seen that data was only collected for two months April and May of 2009. It can also be seen that positive sentiments in May almost not existed, this could help in understand how the alogarith can be develop in case this data will be used for training purpose.

# %%
# As stated above in first visualization, using pivot table can help a lot in plotting
table_dtf = dtf1.pivot(index='date', columns='sentiment', values='test')
table_dtf= table_dtf.fillna(0) # To check no NaN value present in table to avoid error in data 
 
table_dtf.loc[:,[0,1]].plot.bar(stacked=True, color=["gray","orange"], figsize=(14,8))
plt.title('Distribution of Sentiments Based on Date')
plt.ylabel('Number of Recorded Tweets')
plt.legend(['Negative', 'Positive'])

# %% [markdown]
# ## 2.2 US Airlines Visulaization
# As US airlines contain many varibles that can help in visualizing the data, the following approach will be used:
# 1. Like generic tweets, we will visualize data based on total number of positive and negative tweets such that we can know the distribution probability and skewness of the data.
# 2. Data will be visualized based on airlines tweets (as assignment required).

# %% [markdown]
# ### 2.2.1 Visualization of Total Number of Postive and Negative Tweets
# In the first trial of plotting the data, we only plot total number of positive and negative tweets in US airlines, however, as it can be see that negative sentiments overcome postive sentiments, so there is no equal probability. Data is skewed into negative sentiments. Therefore, it would be a good idea to examine negative sentiments based on the negative reason and count number of occurs. From the negative reason plot bar, we can see that most of negative reason in all airlines are associated with customer service issue and late fligh. Therfore, these compnaies have to reevalute their customer service and fligh time. The following plots shows:
# 1. Plot of Total number of positive and negative tweets.
# 2. Plot of negative tweets based on negative reason.

# %%
# The Data pivot_table to plot positive and negative sentiments 
piv_tab3 = pd.pivot_table(clean_USA_dtf,values='test' , index=['sentiment'],aggfunc="count")
dtf3 = pd.DataFrame(piv_tab3.to_records())
print(dtf3)
# Plot bar for total sentiments
my_bag=['Negative', 'Positive']
plt.bar(dtf3.sentiment, dtf3.test)
plt.xticks(dtf3.sentiment, my_bag)
plt.xlabel('sentiment')
plt.ylabel('Number of Recorded Tweets')
plt.title('Distribution of Positive and Negative')
plt.show()
# Out:
#    sentiment  test
# 0          0  9178
# 1          1  2363

# %%
#
piv_tab4 = pd.pivot_table(clean_USA_dtf.loc[clean_USA_dtf['sentiment']== 0] ,values='test' , index=['negative_reason' ],aggfunc="count")
dtf4 = pd.DataFrame(piv_tab4.to_records())
print(dtf4)

# Plot bar for negative reason sentiments
plt.bar(dtf4.negative_reason, dtf4.test)
plt.xlabel('Negative Reason')
plt.ylabel('Number of Recorded Tweets')
plt.xticks(rotation=90) # To rotate words vertically
plt.title("Distribution of Negative Reason Tweets")
plt.show()
# Out:
#                negative_reason  test
# 0                   Bad Flight   580
# 1                   Can't Tell  1190
# 2             Cancelled Flight   847
# 3       Customer Service Issue  2910
# 4              Damaged Luggage    74
# 5  Flight Attendant Complaints   481
# 6      Flight Booking Problems   529
# 7                  Late Flight  1665
# 8                 Lost Luggage   724
# 9                    longlines   178

# %% [markdown]
# ### 2.2.2 Visualization Based on US Airline Tweets
# To carry on visualization based on US airlines tweets, the following steps were proformed.
# 1. Visualizing all positive words for US airlines as word cloud.
# 2. Visualizing all negative words for US airlines as word cloud.
# 3. Capture the tweet that belongs to each airline by usnig "@" hashtages, where "@" was excluded from punctuation in cleaning data function for this purpose.
# 4. As data contains some short forms of airline name, a hashtag dictinary was created to match each form with it long form (a key and its value). Notices all the airlines dictonary key and values were obtained from internet.
# 5. After capturing the tweet, a new column called "twitter_hashtags" was created to sort (appending) each tweet along its correspnding airlines.
# 6. There is possibiity that tweet is written by the airline compnay itself, so we havr to invistigate that and append it to our tweets bag of word list. To do that, it is typical for most of companies to use company name, for example,usairways.
#
# Analysing the plots:
# 1. From the US positve word cloud, we can see that the word "Southwest air", "jetblue" have the highest frequency for positive tweets, along with it we can see words like "best", "amazing", "good customer service", "great", "love", "nice", and "happy" etc.
# 2. From the US negative word cloud, we can see that the word "americanairlines", "unitedairline","usaairways" are the biggest words appeared which indicates more negative responsed associated with that airline tweets.However,"virginamerica" has the smallet word appeared relative to other airlines words, this indicates that public can expect vigine airlines as a good airline compared to others. Along with that, we can also see some negative words such as "cancelled flight", "delayed","help","canceled flight","booking problems", "late flight" and etc.
# 3. United Airlines has the highest number of negative tweets, US Airways and American Airlines takes second and third place in term of number of negative tweets.
# 4. The other airlines Virgin America, SouthWest and JetBlue are having a low negative tweets, this could indicate that they provide a good services compared to United Airlines, US Airways and American Airlines, however, it is still needed to be improved.
# 5. Regarding Delta Assist, as shown below, it has only two negative tweets and zero positive tweets. I would say that data given to us lack information about Delta Assist airline, therefore, no concusion can be made, I might take it out from Modeling preparation step.

# %%
# World Cloud Visualaization for positive tweets of US airlines. 
USA_positive = clean_USA_dtf[clean_USA_dtf['sentiment']==1]
USA_positive_text = USA_positive['text'].apply(lambda text:re.sub("[^a-zA-Z]+", " ", text))

USA_positive_words= pd.Series(USA_positive_text).str.cat(sep=' ')

positive_wordcloud = WordCloud( background_color='black',
                      width=3500,
                      height=3000
                     ).generate(USA_positive_words)

# Plotting word cloud
plt.figure(1,figsize=(12, 12))
plt.imshow(positive_wordcloud)
plt.axis('off')
plt.show()

# %%
# World Cloud Visualaization for positive tweets of US airlines. 
USA_negative = clean_USA_dtf[clean_USA_dtf['sentiment']==0]
USA_negative_text = USA_negative['text'].apply(lambda text:re.sub("[^a-zA-Z]+", " ", text))

USA_negative_words= pd.Series(USA_negative_text).str.cat(sep=' ')

negative_wordcloud = WordCloud( background_color='black',
                      width=3500,
                      height=3000
                     ).generate(USA_negative_words)

# Plotting word cloud
plt.figure(1,figsize=(12, 12))
plt.imshow(negative_wordcloud)
plt.axis('off')
plt.show()

# %% [markdown]
# Hopefully I can get Bonus here for the approach of matching right tweet to exact airline from below code

# %%
# Defining a function that will find all tweets that contains @ and append it to new column named twitter_hashtag
hash_re = re.compile(r'(?:@[\w_]+)')
def find_hash(text):
    return hash_re.findall(text)

clean_USA_dtf['twitter_hashtag']= clean_USA_dtf['text'].apply(lambda x: [x.lower() for x in find_hash(x)])


# Hashtage dictionary created that contains @shortform of airlines name as key and full airline name as value
hashtag_dict = {'@deltaassist':'Delta Assist','@wheelsup':'Wheels Up', '@hawaiianfares':'Hawaiian Airlines', '@porterairlines':'Porter Airlines',
               '@southwestair':'SouthWest Airlines','@virginamerica':'Virgin America','@qantasusa':'Qantas Airways USA','@delta':'Delta',
                '@usairways':'US Airways','@jetblue':'JetBlue Airways','@united':'United Airlines','@flyfrontier':'Frontier Airlines',
                '@alaskaair':'Alaska Airlines','@americanair':'American Airlines','@hawaiianair':'Hawaiian Airlines','@unitedairlines':'United Airlines',
                '@airfranceus':'Air France US', '@cathaypacificus':'Cathay Pacific US', '@flysaa_us':'SouthAfricanAirways','@hainanairlines':'Hainan Airlines'}
# Creating a tweets bag of words
twt_bag_list= []

# A loop was created to search in new added column "twitter_hashtag" for shortform of airlines name and split it and then compare it to hashtag dictionary
for z in clean_USA_dtf['twitter_hashtag']: #searching column
    for y in z:
        y = y.rstrip(string.digits) # splitting words by removing all words other than spcified as sting such that it is clean and ready to be compared in the next line
        if y in hashtag_dict.keys(): # Comparing and checking if airline is in hashtag dictionary
            #print(str(y))
            twt_bag_list.append(hashtag_dict[y]) # Adding word into bag of list
            break
        

# A loop was creaated to check if the tweet made by airline itself, and to do so we search inside user column
count=-1
for z in twt_bag_list:
    count= count+1
    if z == "Unknown":
        check_user = "@"+ str(clean_USA_dtf['user'][count]) # adding @ to user name to match created dictionary keys of airlines names
        check_user = check_user.lower() #converting user name into lowercase as dictionary keys are in lowercase 
        if check_user in hashtag_dict.keys():# checking if user name is in dictinary, it will appended it to bag of list
            twt_bag_list[count] = hashtag_dict[check_user]

column_values = pd.Series(twt_bag_list) #creating a one dimensional series for tweets bag list from dictinary
# Rearrange above process and put all new analysized twt_bag_ into new column names "twitter_hashtags"
clean_USA_dtf.insert(loc=0, column='twitter_hashtags', value=column_values)
clean_USA_dtf= clean_USA_dtf.drop(['twitter_hashtag'], axis=1)

#Visualizing Airlines based on tweets
        
tab5 = pd.pivot_table(clean_USA_dtf, values='test', index=['twitter_hashtags','sentiment'],aggfunc="count")
dtf5= pd.DataFrame(tab5.to_records())

piv_tab5 = dtf5.pivot(index='twitter_hashtags', columns='sentiment', values='test')
piv_tab5= piv_tab5.fillna(0)
piv_tab5
piv_tab5.loc[:,[0,1]].plot.bar(stacked=True, color=["gray","orange"], figsize=(14,8))
plt.xlabel("Airlines")
plt.ylabel("No of Tweets")
plt.legend(["Neative", "Positive"])
plt.title("Distribution of Tweets via Airlines")
plt.show()

# %%
print(piv_tab5)
# Out:
# sentiment              0    1
# twitter_hashtags
# American Airlines   1941  335
# Delta Assist           1    1
# JetBlue Airways      934  506
# SouthWest Airlines  1181  566
# US Airways          2216  297
# United Airlines     2610  492
# Virgin America       178  150

# %% [markdown]
# # 3. Model Preparation
# In this part, based on cleaned date obtained from generic tweet, we will prepare a model by using Countern Vectorizer to give count of the words and frequence and give weightage to the words from frequency.Then conver the text (words) document into a matrix of token counts. To elaborate more,the following steps will be run:
# 1. Extracting tweet text, and removing @ from tweet text, to avoid error during preparing model,why? because I intentially added @ to tweet text to use it to develope a hashtage column contains the airline name for plot and visualization in US airline visulaization setion above.
# 2. Tokenize the words count by using Count Vectorizer and obtain the weight.
# 3. Fit data and convert it into a matrix of token count.
# 4. Splitting data into features (tweets matrix as X) and training data (sentitments as y), where 70% of sentiment will be used for training, and 30% will be used for testing.
# 5. An accuracy function will be defined to perform comparsion between alogarithm, calculate precision, recall, f1-score by using classification report function.
# Accuracy: How many true predictions did the model make.
#     $$accuracy = \frac{correct\ predictions}{samples}$$
#  Recall: For one class, how many of the class samples did the model find in the testing set and correctly identify:
#     $$Recall = \frac{TP}{TP + FN}$$
# Precision :For one class, of all the samples predicted as that class, how many were correct predictions:
#     $$Precision = \frac{TP}{TP + FP}$$
# 6. Naive Bayes Classifer will be used here as it is a method to predict the liklihood that an event will occur give training data. From Naive Bayes, we will use Bernoulli "BNB"as it is good for making predictions from binary feautre since we have a matix that contains 0 and 1.
# 7. Confusion matrix for model is calculated.
# 8. Finally logistic regression score will predicted
# 9. We can compare the results from prediction of Bernoulli abd Logistic regression,based on high score, we will run the model to predict US sentiment in section 4 below.
#
# **Source**:
# 1. Count Victorizer, https://scikit-learn.org/stable/modules/generated/sklearn.feature_extraction.text.CountVectorizer.html?fbclid=IwAR1uz3a5CINz0pKd-Xd6yU8jASbSJ0GcGSE8Cf0eg_nnpGRHzn2dsOlBhxk

# %% [markdown]
# ## 3.1 Prepare Model from Generic Tweets

# %%
# Exctracting only the text from clean generic tweets 
generic_tweets = clean_dtf['text'].apply(lambda text:re.sub("[^a-zA-Z]+", " ", text))
#print(generic_tweets)

# Using Count Vectorization to tokenize the words and then develope matric of token counts
vectorizer = CountVectorizer(stop_words="english", analyzer='word', ngram_range=(1, 1), max_df=1.0, min_df=1, max_features=None)
vectorizer.fit(generic_tweets)
txt_fitted_generic_CV = vectorizer.fit_transform(generic_tweets)

# Splitting features data into training and testing 
X = txt_fitted_generic_CV
y = clean_dtf['sentiment'] 

X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.3)

#finding the disctinct categories for sentiment in generic tweets
category_id_df = clean_dtf['sentiment'].drop_duplicates()
category_to_id = list(category_id_df.values)

# %%
# Defining a function for the performance comparison of different algorithms
def algorithm_accuracy(X_train, X_test, y_train, y_test):
    
    R_name,logR=(('LogR', LogisticRegression()))
    BER_name,BNB=(('BNB', BernoulliNB()))
    
    BER_model=BNB.fit(X_train,y_train)#fitting by using Bernoulli 
    by_predict = BER_model.predict(X_test)#preducting by using test 
    BER_score = accuracy_score(y_test,by_predict)# evaluate the accuracy due to using Bernoulli
    
    
    R_model = logR.fit(X_train,y_train) # Training the model
    y_predict = R_model.predict(X_test) # Predicting the test data
    R_score = accuracy_score(y_test,y_predict) #Evaluating the accuracy of the model
    
    print(BER_name)
    print(classification_report(y_test,by_predict))
    print('------------------------------------------')
    
    
    cm = confusion_matrix(by_predict, y_test) # Finding the confusing matrix for the first model for Bernoulli+Plot
    fig, ax = plt.subplots(figsize=(10,10))
    sns.heatmap(cm, annot=True, fmt='d',
            xticklabels=category_to_id, yticklabels=category_to_id)

    plt.ylabel('Actual')
    plt.xlabel('Predicted')
    plt.show()

    print(cm)
    print(by_predict)
    print('------------------------------------------')
    print(BER_name)
    print(BER_score) 
    
    print(R_name)
    print(classification_report(y_test,y_predict))
    print('------------------------------------------')
    
    cm = confusion_matrix(y_predict, y_test) # Finding the confusing matrix for the first model Logistic Regression+Plot
    fig, ax = plt.subplots(figsize=(10,10))
    sns.heatmap(cm, annot=True, fmt='d',xticklabels=category_to_id, yticklabels=category_to_id)
    plt.ylabel('Actual')
    plt.xlabel('Predicted')
    plt.show() 
    
    print(cm)
    print(y_predict)
    print('------------------------------------------')
    print(R_name)
    print(R_score) 
    return R_score
      
# calling the function
algorithm_accuracy(X_train,X_test, y_train, y_test)
# Out:
# C:\Users\Mohammed\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# BNB
#               precision    recall  f1-score   support
#
#            0       0.72      0.77      0.74     29964
#            1       0.75      0.70      0.73     30036
#
#    micro avg       0.74      0.74      0.74     60000
#    macro avg       0.74      0.74      0.74     60000
# weighted avg       0.74      0.74      0.74     60000
#
# ------------------------------------------
# [[23000  8895]
#  [ 6964 21141]]
# [0 0 1 ... 1 1 1]
# ------------------------------------------
# BNB
# 0.7356833333333334
# LogR
#               precision    recall  f1-score   support
#
#            0       0.75      0.71      0.73     29964
#            1       0.73      0.77      0.75     30036
#
#    micro avg       0.74      0.74      0.74     60000
#    macro avg       0.74      0.74      0.74     60000
# weighted avg       0.74      0.74      0.74     60000
#
# ------------------------------------------
# [[21303  6959]
#  [ 8661 23077]]
# [1 0 1 ... 1 1 0]
# ------------------------------------------
# LogR
# 0.7396666666666667
# 0.7396666666666667

# %% [markdown]
# From above report for both models Bernoulli and LogRe, we can see that we have a balance F1 score, that means we have equal positive and negative in training data from Generic tweets and this is confirms from above plots of positive and negative for generic plots

# %% [markdown]
# # 4. Model Implmentation
#
# After the model was prepared above from the generic tweets where Bernoulli model gives an average accuracy of , and logitic regression gives an average accuracy of . Therefore, to predict US airline sentiment we would use the Bernoulli model. Then testing model to predict sentiment for US airline from the trained model.
#
# Another model will be prepared from US airlines negative tweets only to predict negative_reasons by using a pipeline assembly technique that proforms TFIDF, SelectKBest and Logistic Regression.
#
# The Purpose in this section is that, in first model I used Counter Victorizer, and in second model I used TFIDF for purpose of familarized myself with different libraries.
#
# 1. Testing Generic tweet model on the US airline data to predict the sentiments.
# 2. Multi class logistic regression to predict the reason for the negative tweets.

# %% [markdown]
# ## 4.1 Training US Airline Tweets and Predict the Sentiment

# %%
# Extracting only text tweet from clean US airlines data, and removing @ from text.
US_airlines = clean_USA_dtf['text'].apply(lambda text:re.sub("[^a-zA-Z]+", " ", text))
#print(US_airlines)

# Transforming the US_Airlines tweets in matrix word counts
txt_fitted_airlines_CV = vectorizer.transform(US_airlines)

# Defining training data the X and y values
X = txt_fitted_generic_CV # features from generic tweets
y = clean_dtf['sentiment'] # response or sentiments from generic tweets

# Defining training data fron US airlines tweets and predicted sentiment
X_test = txt_fitted_airlines_CV #tested tweets from US airline tweets 
y_test = clean_USA_dtf['sentiment'] # predicted sentiment for US airlines tweets

#finding the disctinct categories for sentiment in US airlines tweets
category_id_df = clean_USA_dtf['sentiment'].drop_duplicates()
category_to_id = list(category_id_df.values)

# Calling the algorithm_accuracy function
Result_Training = algorithm_accuracy(X, X_test, y, y_test)
# Out:
# C:\Users\Mohammed\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# BNB
#               precision    recall  f1-score   support
#
#            0       0.89      0.82      0.85      9178
#            1       0.46      0.61      0.52      2363
#
#    micro avg       0.77      0.77      0.77     11541
#    macro avg       0.67      0.71      0.69     11541
# weighted avg       0.80      0.77      0.78     11541
#
# ------------------------------------------
# [[7484  929]
#  [1694 1434]]
# [1 1 0 ... 0 0 0]
# ------------------------------------------
# BNB
# 0.7727233341998094
# LogR
#               precision    recall  f1-score   support
#
#            0       0.91      0.75      0.83      9178
#            1       0.43      0.73      0.54      2363
#
#    micro avg       0.75      0.75      0.75     11541
#    macro avg       0.67      0.74      0.68     11541
# weighted avg       0.82      0.75      0.77     11541
#
# ------------------------------------------
# [[6913  649]
#  [2265 1714]]
# [0 1 0 ... 0 0 0]
# ------------------------------------------
# LogR
# 0.7475088813794298

# %% [markdown]
# Bernoulli model gives us an accuracy of 77.2%, while LogRe gives an accuracy of 74.7%
# The total average in both models is balance for F1 at 74.6%.
# The F1 score of positive (0.54) and negative (0.83) is not balanced. That is because data provided to us is skwed into negative. Improvement will be discussed at Discussion section.
#
# As Bernoulli Model gives us the highest accuracy score, we will use Bernoulli model to predict US airlines sentiments below.

# %%
# Running the Bernoulli NB model to check the predicted US_Airline tweets as it has a higher score 0.77 than LogR 0.74
model = BernoulliNB()
model = model.fit(X,y) # Training the model
y_predict = model.predict(X_test)
Predicted_sentiment = pd.DataFrame({'sentiment':y_predict})
clean_USA_dtf['Predicted_sentiment'] = Predicted_sentiment
clean_USA_dtf['Predicted_sentiment']
clean_USA_dtf.head()
# Out:
#   twitter_hashtags        user  sentiment  test  retweet_count  \
# 0   Virgin America    jnardino          1     0              0
# 1   Virgin America    jnardino          0     0              0
# 2   Virgin America    jnardino          0     0              0
# 3   Virgin America    jnardino          0     0              0
# 4   Virgin America  cjmcginnis          1     0              0
#
#   negative_reason                                               text  \
# 0                     @virginamerica ve commercials experience tacky
# 1      Bad Flight  @virginamerica aggressive blast obnoxious ente...
# 2      Can't Tell                       @virginamerica big bad thing
# 3      Can't Tell  @virginamerica seriously pay flight seats didn...
# 4                            @virginamerica time fly vx ear worm won
#
#    Predicted_sentiment
# 0                    1
# 1                    1
# 2                    0
# 3                    0
# 4                    0

# %% [markdown]
# ## 4.2 Multi Class Logistic Regression on Negative Reasons
# In this part, we will build a model to predict negative reason from negative US airlines by using pipeline function to assemble all task and give back the result when it is caled.The following steps were performed:
#
# 1. **Term frequency - inverse document frequency method**(**TFIDF**), this function will take a set of words from negative tweet to use it as a feature and give it a weight. In addition to that, words with less liklehood to occure will be removed.
#
#
# 2. **SelectKbest**: I will use selectKbest with Chi-squared stats of non-negative features for classification. In addition, i will give K a value of 400. Putting this together, it will give the highest K statistical score for negative the features which I will used to train.
#
# 3. **logistic regression**: to estimate score of the model. At the LogR we will give it some parameters to train model to give the best possible score. "C" , used for complexity of regression, such that smaller values specify stronger regularization. "max_iter",it represents the maximum number of iteration taken to converge.
#
#
#
# **Sources**:
# 1. TFIDF, http://aimotion.blogspot.com/2011/12/machine-learning-with-python-meeting-tf.html
# 2. TFIDF, https://medium.freecodecamp.org/how-to-process-textual-data-using-tf-idf-in-python-cd2bbc0a94a3
# 3. SelectKbest, https://scikit-learn.org/stable/modules/generated/sklearn.feature_selection.SelectKBest.html
# 4. logistic regreesion, https://scikit-learn.org/stable/modules/generated/sklearn.linear_model.LogisticRegression.html

# %%
# Exctracting only the negative sentiments from US airline tweets
Neg_dtf_USA = clean_USA_dtf.loc[clean_USA_dtf['sentiment'] == 0]

# Removing the @ from cleaned US airline tweets and splitting data into training 70% and testing 30% 
X_USA = Neg_dtf_USA['text'].apply(lambda text:re.sub("[^a-zA-Z]+", " ", text))
y_USA = Neg_dtf_USA['negative_reason']
X_USA_train, X_USA_test, y_USA_train, y_USA_test = train_test_split(X_USA,y_USA,test_size=0.3)

# %%
#finding the disctinct categories for negative reason in US airline tweets
category_id_df =Neg_dtf_USA['negative_reason'].drop_duplicates()
category_to_id = list(category_id_df.values)

#Pipeline for tuned Model
pipeline= Pipeline([('vect', TfidfVectorizer(ngram_range=(1,1), min_df = 5, max_df = 3000,  stop_words = None,  norm = 'l2', binary = False, sublinear_tf = False)),
                      ('chi', SelectKBest(chi2, 400)),
                      ('clf', LogisticRegression(C=2.0, max_iter= 300))]) 
                                                                       
#passing the training features and responses into pipline to victorize it and then making the predictions for both the models
model = pipeline.fit(X_USA_train,y_USA_train) 
prediction= model.predict(X_USA_test)
score = accuracy_score(y_USA_test,prediction)
print ("Score  :"+str(score*100))

#Classification report for Raw model
print(classification_report(y_USA_test,prediction))

#Confusion Matrix for Raw model
conf_mat2 = confusion_matrix(y_USA_test, prediction)

#plotting confusion matrix
fig, ax = plt.subplots(figsize=(10,10))
sns.heatmap(conf_mat2, annot=True, fmt='d',xticklabels=category_to_id, yticklabels=category_to_id)
plt.ylabel('Actual')
plt.xlabel('Predicted')
plt.show()
# Out:
# C:\Users\Mohammed\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\Mohammed\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:460: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# C:\Users\Mohammed\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1143: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\Mohammed\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1143: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# Score  :61.22004357298475
#                              precision    recall  f1-score   support
#
#                  Bad Flight       0.57      0.35      0.43       166
#                  Can't Tell       0.42      0.45      0.44       354
#            Cancelled Flight       0.77      0.66      0.71       281
#      Customer Service Issue       0.61      0.78      0.68       877
#             Damaged Luggage       0.00      0.00      0.00        22
# Flight Attendant Complaints       0.63      0.30      0.41       133
#     Flight Booking Problems       0.55      0.29      0.38       151
#                 Late Flight       0.66      0.72      0.69       503
#                Lost Luggage       0.72      0.68      0.70       213
#                   longlines       0.67      0.04      0.07        54
#
#                   micro avg       0.61      0.61      0.61      2754
#                   macro avg       0.56      0.43      0.45      2754
#                weighted avg       0.61      0.61      0.59      2754
# C:\Users\Mohammed\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1143: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)

# %%
# Check and test prediction
Training_Pr_Results = pd.DataFrame({'true':y_USA_test,'predicted_negative_reason':prediction,'text':X_USA_test })

Wrong_Prediction = Training_Pr_Results[(Training_Pr_Results['predicted_negative_reason'] != Training_Pr_Results['true'] )]
Wrong_Prediction.head(15)
# Out:
#                           true predicted_negative_reason  \
# 1836   Flight Booking Problems    Customer Service Issue
# 11241              Late Flight              Lost Luggage
# 7265               Late Flight    Customer Service Issue
# 10209  Flight Booking Problems    Customer Service Issue
# 6687               Late Flight                Can't Tell
# 7527    Customer Service Issue               Late Flight
# 11352         Cancelled Flight    Customer Service Issue
# 7701          Cancelled Flight    Customer Service Issue
# 2584    Customer Service Issue               Late Flight
# 231                Late Flight    Customer Service Issue
# 10442  Flight Booking Problems    Customer Service Issue
# 1916                Can't Tell    Customer Service Issue
# 5303                Can't Tell    Customer Service Issue
# 8066                Can't Tell               Late Flight
# 10233              Late Flight    Customer Service Issue
#
#                                                     text
# 1836    united guys changed ages double booked seats ...
# 11241   americanair ny njairports aa mins priority ba...
# 7265    usairways pls tallahassee stranded gainesvill...
# 10209   americanair guys rid functionality reservatio...
# 6687    jetblue telling hotel food spend money guys c...
# 7527    usairways airlines la rdu holding baggages ho...
# 11352   americanair flt cancelled flighted reschedule...
# 7701    usairways costing today reason send receipts ...
# 2584    united concept customer service connection de...
# 231        virginamerica spending birthday night dal dca
# 10442   americanair friend legally required chaperone...
# 1916    united insulted disrespected met incompetence...
# 5303    jetblue hopefully will help future procedure ...
# 8066          usairways cutting pregame time kentuckymbb
# 10233   americanair sitting plane hour unacceptable c...

# %%
#plotting the predicted negative reason
USA_piv_table6 = pd.pivot_table(Wrong_Prediction, values='text', index=['predicted_negative_reason' ],aggfunc="count")
USA_Netb6= pd.DataFrame(USA_piv_table6.to_records())

plt.bar(USA_Netb6.predicted_negative_reason, USA_Netb6.text)
plt.xlabel('Reason')
plt.ylabel('No of records')
plt.xticks(rotation=90)
plt.title("Distribution of Wrong Predict Negative Reviews")
plt.show()

# %% [markdown]
# # 5. Results and Discussion
# In this section, I will answer questions provided in the assignment:
# 1. **What can public opinion on twitter tell us about the US airlines in 2015?**
# To answer this question in depth, we have to look first into the plot of total number of positive and negative sentiment for USA airline. It is clearly shown that data is skewed into negative sentiments (9178 out of 11541). One more thing we can also look at is positive and negative sentiment for each tweet coresspond to each airline as shown in above plot at section two of  visulaization, the data is not uniformly disterbuted, Why?? It could be that data was collected for only short period (Maybe two months or less, it could be also a fraud user is filling the tweets with negaitve response causing uniform distributions. This can be also shown that for Delta airlines the response I got from my analysi is only one negative and one positive, this is clearly demonstrate why we have not uniform data. So The public judgment based on this visialization analysis (wordCloud for positive and negative airline in addition to bar plot) will be the following:
#
# *Southwest airlines, Jetblue and virgine America airlines have highest positve sentiment as well as less negative sentiments compared to other airlines. Therefore, they will be viewd as better airlines than others.
#
# *As Delta airlines does not have enough good records for sentiments, I can not make any judgment at all, I would delte it from the column, but I keept it for purpose of explaination.
#
# *For more validation skewness of US airlines, when train and predict data,the outcome score of F1 is not balance at all for posotive and negative sentiments.

# %%
my_bag=['Negative', 'Positive']
plt.bar(dtf2.sentiment, dtf2.test)
plt.xticks(dtf2.sentiment, my_bag)
plt.xlabel('Sentiment')
plt.ylabel('Number of Recorded Tweets')
plt.title('Distribution of Positive and Negative')
plt.show()
clean_dtf.sentiment.value_counts()

print("-----------------------------------------------------------------")

# As stated above in first visualization, using pivot table can help a lot in plotting
table_dtf = dtf1.pivot(index='date', columns='sentiment', values='test')
table_dtf= table_dtf.fillna(0) # To check no NaN value present in table to avoid error in data 
 
table_dtf.loc[:,[0,1]].plot.bar(stacked=True, color=["gray","orange"], figsize=(14,8))
plt.title('Distribution of Sentiments Based on Date')
plt.ylabel('Number of Recorded Tweets')
plt.legend(['Negative', 'Positive'])
plt.show()

print("-----------------------------------------------------------------")

print('World Cloud Visualaization for negative tweets of US airlines')
# World Cloud Visualaization for positive tweets of US airlines. 
USA_positive = clean_USA_dtf[clean_USA_dtf['sentiment']==1]
USA_positive_text = USA_positive['text'].apply(lambda text:re.sub("[^a-zA-Z]+", " ", text))

USA_positive_words= pd.Series(USA_positive_text).str.cat(sep=' ')

positive_wordcloud = WordCloud( background_color='black',
                      width=3500,
                      height=3000
                     ).generate(USA_positive_words)

# Plotting word cloud
plt.figure(1,figsize=(12, 12))
plt.imshow(positive_wordcloud)
plt.axis('off')
plt.show()

print("-----------------------------------------------------------------")

print('World Cloud Visualaization for positive tweets of US airlines')
# World Cloud Visualaization for positive tweets of US airlines. 
USA_negative = clean_USA_dtf[clean_USA_dtf['sentiment']==0]
USA_negative_text = USA_negative['text'].apply(lambda text:re.sub("[^a-zA-Z]+", " ", text))

USA_negative_words= pd.Series(USA_negative_text).str.cat(sep=' ')

negative_wordcloud = WordCloud( background_color='black',
                      width=3500,
                      height=3000
                     ).generate(USA_negative_words)

# Plotting word cloud
plt.figure(1,figsize=(12, 12))
plt.imshow(negative_wordcloud)
plt.axis('off')
plt.show()

print("-----------------------------------------------------------------")

#Visualizing Airlines based on tweets
        
tab5 = pd.pivot_table(clean_USA_dtf, values='test', index=['twitter_hashtags','sentiment'],aggfunc="count")
dtf5= pd.DataFrame(tab5.to_records())

piv_tab5 = dtf5.pivot(index='twitter_hashtags', columns='sentiment', values='test')
piv_tab5= piv_tab5.fillna(0)
piv_tab5
piv_tab5.loc[:,[0,1]].plot.bar(stacked=True, color=["gray","orange"], figsize=(14,8))
plt.xlabel("Airlines")
plt.ylabel("No of Tweets")
plt.legend(["Neative", "Positive"])
plt.title("Distribution of Tweets via Airlines")
plt.show()
# Out:
# -----------------------------------------------------------------
# -----------------------------------------------------------------
# World Cloud Visualaization for negative tweets of US airlines
# -----------------------------------------------------------------
# World Cloud Visualaization for positive tweets of US airlines
# -----------------------------------------------------------------

# %% [markdown]
# 2. Reasons why your model does not predict efficiently.
# #### Model No1: Predicting the USA airline sentiments from generic tweets data:
# From distribution plot of generic tweets, we have equal positive and negative sentiment (50% probability each) each same for F1 score, both are balanced, so it would be fine to train the model, but why we still have unbalance F1 score when we train USA airlines???? The following could be the reason:
# *The data for generic tweets is not related to airlines data, as both could have different work or industrial termonlogies to be used. At cleaning process, we used stop words for generic tweets that probably missing some industrial keywords whcih is not important for our model.Thus, missing these words in stop_words could increase the error in airlinw data as we cleaned them.
#
# *We can improve the accuracy of the model by adding some industrial words into  stop_words file, sush that during cleaning we will be sure that only important words are remained to be used for training.
#
# *Another way we can improve the accuracy of the model is setting a dictionary that contains contraction of word and its value is full form of contraction word.Doing this during cleaning and before removing stop_words could increase accuracy as words that will be removed are complete so no missing part of a word will be left.
#
# #### Model No 2: Predicting negative USA airlines reason from negative USA sentiments:
# The alogarithm for predicting and model both function perfectly, the issue behind failing to predict and having a high balanced F1 score is that negative_reasons are not classified or grouped for specific type of tweets, in addition to that the number of negative tweets for each negative_reason are not EQUAL at all, this type of distribution will make the confused and failing to predict negative reason. See below the actual predicted results for model 2:

# %%
# Check and test prediction
Training_Pr_Results = pd.DataFrame({'true':y_USA_test,'predicted_negative_reason':prediction,'text':X_USA_test })

Wrong_Prediction = Training_Pr_Results[(Training_Pr_Results['predicted_negative_reason'] != Training_Pr_Results['true'] )]
Wrong_Prediction.head(15)

USA_piv_table6 = pd.pivot_table(Wrong_Prediction, values='text', index=['predicted_negative_reason' ],aggfunc="count")
USA_Netb6= pd.DataFrame(USA_piv_table6.to_records())

plt.bar(USA_Netb6.predicted_negative_reason, USA_Netb6.text)
plt.xlabel('Reason')
plt.ylabel('No of records')
plt.xticks(rotation=90)
plt.title("Distribution of Wrong Predict Negative Reviews")
plt.show()
print("-----------------------------------------------------------------")
plt.bar(dtf4.negative_reason, dtf4.test)
plt.xlabel('Negative Reason')
plt.ylabel('Number of Recorded Tweets')
plt.xticks(rotation=90) # To rotate words vertically
plt.title("Distribution of Actual Negative Reason Tweets")
plt.show()
# Out:
# -----------------------------------------------------------------

# %% [markdown]
# #### To improve Model No 2,
# we have to group each class of negative_reason with respect to negative tweets such that we can improve model prediction as shown below here. We were able to improve model from 61.2% to 74.1% in by using LogReg

# %%
#finding the disctinct categories for negative reason in US airline tweets
#category_id_df =Neg_dtf_USA['negative_reason'].drop_duplicates()


# Extracting only text tweet from clean US airlines data, and removing @ from text.
US_airlines_stext = clean_USA_dtf['text'].apply(lambda text:re.sub("[^a-zA-Z]+", " ", text))

# Using Count Vectorization to tokenize the words and give the count of the words as done previously in logistic regression.-
vectorizer = CountVectorizer(stop_words="english", analyzer='word', ngram_range=(1, 1), max_df=1.0, min_df=1, max_features=None)
vectorizer.fit(US_airlines_stext)
fitted_airlines = vectorizer.fit_transform(US_airlines_stext)

# Grouping neagtive_reason classes 
list1 = ['Bad Flight' , 'Late Flight' , 'Cancelled Flight','Damaged Luggage','Lost Luggage']
list2 = ['Flight Booking Problems' , 'Customer Service Issue','Flight Attendant Complaints','longlines','Can\'t Tell']

category_to_id = (list1,list2)
Negative_Rea_Scoring =[]
reasons = clean_USA_dtf['negative_reason']
for x in reasons:
    if x in list1:
        Negative_Rea_Scoring.append(1)
    elif x in list2:
        Negative_Rea_Scoring.append(2)
    else:
        Negative_Rea_Scoring.append(0)

clean_USA_dtf['Negative_Grouped_Scoring'] = Negative_Rea_Scoring

#Defining the X and y values
X = fitted_airlines
y = clean_USA_dtf['Negative_Grouped_Scoring']

# Splitting the dataset into training/testing set
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.3)

#calling the function
result_3 = algorithm_accuracy(X_train,X_test, y_train, y_test)
# Out:
# C:\Users\Mohammed\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\Mohammed\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:460: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# BNB
#               precision    recall  f1-score   support
#
#            0       0.77      0.47      0.58       705
#            1       0.73      0.70      0.71      1155
#            2       0.68      0.81      0.74      1603
#
#    micro avg       0.70      0.70      0.70      3463
#    macro avg       0.72      0.66      0.68      3463
# weighted avg       0.71      0.70      0.70      3463
#
# ------------------------------------------
# [[ 332   36   64]
#  [  66  805  238]
#  [ 307  314 1301]]
# [2 1 2 ... 0 2 1]
# ------------------------------------------
# BNB
# 0.7040138608143228
# LogR
#               precision    recall  f1-score   support
#
#            0       0.73      0.67      0.70       705
#            1       0.74      0.72      0.73      1155
#            2       0.74      0.79      0.77      1603
#
#    micro avg       0.74      0.74      0.74      3463
#    macro avg       0.74      0.73      0.73      3463
# weighted avg       0.74      0.74      0.74      3463
#
# ------------------------------------------
# [[ 474   60  118]
#  [  63  830  223]
#  [ 168  265 1262]]
# [1 1 2 ... 0 1 1]
# ------------------------------------------
# LogR
# 0.7409760323419001

# %% [markdown]
# #### General possible to improve accuracy score for models.
# 1. Traing the model by varying features (tweets weight).
# 2. We can train model by using Bi gram models.
# 3. Train the model with most frequent words from the generic tweets or airline tweets.
